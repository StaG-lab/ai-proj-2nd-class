# %%
import pandas as pd
from sqlalchemy import create_engine, text
from datetime import date, timedelta, time 
import json

with open("./db_config.json", "r") as f:
    config = json.load(f)
    
DB_USER = config["DB_USER"]
DB_PASSWORD = config["DB_PASSWORD"]
DB_HOST = config["DB_HOST"]
DB_NAME = config["DB_NAME"]
DB_PORT = config["DB_PORT"]

# SQLAlchemy 엔진 생성
engine_url = f"mysql+pymysql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"

try:
    engine = create_engine(engine_url)
    print("MySQL 데이터베이스에 성공적으로 연결되었습니다.")
except Exception as e:
    print(f"데이터베이스 연결 오류: {e}")
    exit()

# --- 데이터베이스에서 데이터 로드하는 함수 ---
def load_table_to_df(table_name, engine):
    """지정된 테이블에서 모든 데이터를 Pandas DataFrame으로 로드합니다."""
    try:
        query = f"SELECT * FROM {table_name}"
        df = pd.read_sql(query, engine)
        print(f"'{table_name}' 테이블 로드 완료. {len(df)} 행.")
        # 날짜/시간 컬럼 타입 변환 (필요시)
        if 'game_date' in df.columns:
            df['game_date'] = pd.to_datetime(df['game_date'])
        if 'accident_date' in df.columns:
            df['accident_date'] = pd.to_datetime(df['accident_date'])
        if 'weather_date' in df.columns:
            df['weather_date'] = pd.to_datetime(df['weather_date'])
        # start_time, end_time, weather_time은 문자열로 로드될 수 있으므로, 필요시 time 객체로 변환
        return df
    except Exception as e:
        print(f"'{table_name}' 테이블 로드 중 오류 발생: {e}")
        return pd.DataFrame() # 오류 발생 시 빈 DataFrame 반환

# --- 데이터 로드 ---
stadium_df = load_table_to_df('stadium', engine)
sports_game_df = load_table_to_df('sports_game', engine)
traffic_accident_df = load_table_to_df('traffic_accident', engine)
weather_df = load_table_to_df('weather', engine)

# 데이터베이스 연결 종료
if 'engine' in locals() and engine:
    engine.dispose()
    print("\n데이터베이스 연결이 종료되었습니다.")
# Out:
# MySQL 데이터베이스에 성공적으로 연결되었습니다.
# 'stadium' 테이블 로드 완료. 60 행.
# 'sports_game' 테이블 로드 완료. 3631 행.
# 'traffic_accident' 테이블 로드 완료. 34032 행.
# 'weather' 테이블 로드 완료. 450811 행.
#
# 데이터베이스 연결이 종료되었습니다.

# %%
# 야구 관중수 정보
df_kbo_audience = pd.read_csv('./dataset/야구_kbo_관중수_2023_2024.csv', encoding='utf-8')
stadium_code_map = {
    "사직": "BS02",
    "청주": "CJ01",
    "창원": "CW01",
    "대구": "DG03",
    "대전": "DJ02",
    "광주": "GJ02",
    "문학": "IC02",
    "이천": "IH01",
    "포항": "PH02",
    "고척": "SO04",
    "잠실": "SO05",
    "수원": "SU03",
    "울산": "US03"
}

df_kbo_audience["stadium_code"] = df_kbo_audience["구장"].map(stadium_code_map)
df_kbo_audience['날짜'] = pd.to_datetime(df_kbo_audience['날짜'], format="%Y.%m.%d").dt.date
df_kbo_audience['관중수'] = df_kbo_audience['관중수'].str.replace(',', '').astype(int)
df_kbo_audience.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1440 entries, 0 to 1439
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   연도            1440 non-null   int64
#  1   날짜            1440 non-null   object
#  2   요일            1440 non-null   object
#  3   홈             1440 non-null   object
#  4   방문            1440 non-null   object
#  5   구장            1440 non-null   object
#  6   관중수           1440 non-null   int32
#  7   stadium_code  1440 non-null   object
# dtypes: int32(1), int64(1), object(6)
# memory usage: 84.5+ KB

# %%
# 축구 관중수
df_klg_audience = pd.read_csv('./dataset/축구_k-league_관중수_2023_2024.csv', encoding='utf-8')
klg_stadium_codemap = {
    "부산 아시아드": "BS01",
    "천안 종합": "CA01",
    "춘천 송암": "CC01",
    "대구iM뱅크PARK": "DG01",
    "대구 스타디움": "DG02",
    "대전 월드컵": "DJ01",
    "김천 종합": "GC01",
    "광주 전용": "GJ01",
    "강릉 종합": "GN01",
    "김포 솔터": "GP01",
    "인천 전용": "IC01",
    "제주 월드컵": "JE01",
    "전주 월드컵": "JJ01",
    "포항 스틸야드": "PH01",
    "서울 월드컵": "SO01",
    "상암 보조": "SO02",
    "목동 종합": "SO03",
    "수원 월드컵": "SU01",
    "수원 종합": "SU02",
    "울산 문수": "US01",
    "울산 종합": "US02"
}



df_klg_audience["stadium_code"] = df_klg_audience["경기장"].map(klg_stadium_codemap)
df_klg_audience['일자'] = pd.to_datetime(df_klg_audience['일자'], format="%Y.%m.%d").dt.date
df_klg_audience['관중수'] = df_klg_audience['관중수'].str.replace(',', '').astype(int)
df_klg_audience['원정팀'] = df_klg_audience['원정팀'].str.replace(',', '').astype(int)
df_klg_audience.head()
# Out:
#      시즌    대회             대회명  경기번호          일자  홈팀    상대  경기결과      경기장  \
# 0  2023  K리그1  하나원큐 K리그1 2023     1  2023-02-25  울산    전북  2:01    울산 문수
# 1  2023  K리그1  하나원큐 K리그1 2023     2  2023-02-25  서울    인천  2:01   서울 월드컵
# 2  2023  K리그1  하나원큐 K리그1 2023     3  2023-02-25  수원    광주  0:01   수원 월드컵
# 3  2023  K리그1  하나원큐 K리그1 2023     4  2023-02-26  포항    대구  3:02  포항 스틸야드
# 4  2023  K리그1  하나원큐 K리그1 2023     5  2023-02-26  제주  수원FC  0:00   제주 월드컵
#
#      관중수   원정팀  비고 stadium_code
# 0  28039  2037  주말         US01
# 1  22204  3216  주말         SO01
# 2  10348   409  주말         SU01
# 3  14089  1152  주말         PH01
# 4   8362   181  주말         JE01

# %%
# 배구 관중수
df_vlg_audience = pd.read_csv('./dataset/배구_vl_관중수_2023_2024.csv', encoding='utf-8')
vlg_stadium_codemap = {
    "안산상록수체육관": "AS01",
    "천안유관순체육관": "CA02",
    "대전충무체육관": "DJ04",
    "김천실내체육관": "GC02",
    "구미박정희체육관": "GM01",
    "페퍼스타디움": "HS01",
    "화성종합실내체육관": "HS02",
    "인천계양체육관": "IC03",
    "인천삼산월드체육관": "IC04",
    "서울장충체육관": "SO08",
    "수원체육관": "SU05",
    "의정부체육관": "UJ01",
    "경민대학교 기념관(체육관)": "UJ02"
}

df_vlg_audience["stadium_code"] = df_vlg_audience["place"].map(vlg_stadium_codemap)
df_vlg_audience["gDate"] = pd.to_datetime(df_vlg_audience["gDate"], format="%Y.%m.%d").dt.date
#print(df_vlg_audience['gDate'].apply(type).value_counts())
df_vlg_audience.head()
# Out:
#    hTeamCode  aTeamCode       gDate  sTime  eTime  hSetPoint  aSetPoint  \
# 0       1001       1004  2022-10-22  14:00  16:03          3          1
# 1       2001       2002  2022-10-22  14:00  15:29          3          0
# 2       1008       1006  2022-10-23  14:25  15:57          0          3
# 3       2006       2005  2022-10-23  16:00  17:31          0          3
# 4       1002       1005  2022-10-25  19:00  21:05          1          3
#
#        place city  spectators aTeamName totalTime  fetch_gNum  \
# 0    인천계양체육관   인천        1987    KB손해보험      1:52           1
# 1      수원체육관   수원        2913    한국도로공사      1:21           2
# 2   안산상록수체육관   안산        1661      한국전력      1:24           3
# 3  화성종합실내체육관   화성        2579     GS칼텍스      1:23           4
# 4    대전충무체육관   대전         931     현대캐피탈      1:54           5
#
#    fetch_gPart_success stadium_code
# 0                  201         IC03
# 1                  201         SU05
# 2                  201         AS01
# 3                  201         HS02
# 4                  201         DJ04

# %%
# 야구 관중수 병합
sports_game_with_audience_df = sports_game_df.copy()
sports_game_with_audience_df['audience'] = pd.NA

sports_game_with_audience_df.loc[sports_game_with_audience_df['stadium_code'] == 'DJ03', 'stadium_code'] = 'DJ02'

df_kbo_audience_prepared = df_kbo_audience.copy()
df_kbo_audience_prepared['date_kbo'] = pd.to_datetime(df_kbo_audience_prepared['날짜'])

# 관중수 컬럼명을 임시로 변경 (충돌 방지)
df_kbo_audience_prepared.rename(columns={'관중수':'audience_temp_kbo'}, inplace=True)
# KBO 데이터 병합
sports_game_with_audience_df = sports_game_with_audience_df.merge(
    df_kbo_audience_prepared[['stadium_code', 'date_kbo', 'audience_temp_kbo']],
    left_on=['stadium_code', 'game_date'],
    right_on=['stadium_code', 'date_kbo'],
    how='left'
)

# 'audience' 컬럼 업데이트 및 임시 컬럼 삭제
sports_game_with_audience_df['audience'] = sports_game_with_audience_df['audience'].combine_first(sports_game_with_audience_df['audience_temp_kbo'])
sports_game_with_audience_df.drop(columns=['date_kbo', 'audience_temp_kbo'], inplace=True, errors='ignore')

print("--- KBO 병합 후 ---")
print(sports_game_with_audience_df)
sports_game_with_audience_df.info()
print("\n")
# Out:
# --- KBO 병합 후 ---
#       game_id stadium_code sports_type  game_date day_of_week is_holiday  \
# 0           1         DJ02          야구 2023-03-13           월       None
# 1           2         SO04          야구 2023-03-13           월       None
# 2           3         CW01          야구 2023-03-13           월       None
# 3           4         BS02          야구 2023-03-13           월       None
# 4           5         DG03          야구 2023-03-13           월       None
# ...       ...          ...         ...        ...         ...        ...
# 3672     3627         HS01        여자배구 2024-12-26           목       None
# 3673     3628         HS02        여자배구 2024-12-27           금       None
# 3674     3629         IC04        여자배구 2024-12-28           토       None
# 3675     3630         HS01        여자배구 2024-12-29           일       None
# 3676     3631         DJ04        여자배구 2024-12-31           화       None
#
#           start_time        end_time  home_team_win match_type  audience
# 0    0 days 14:00:00 0 days 17:00:00              1       시범경기       NaN
# 1    0 days 14:00:00 0 days 17:00:00              0       시범경기       NaN
# 2    0 days 14:00:00 0 days 17:00:00              0       시범경기       NaN
# 3    0 days 14:00:00 0 days 17:00:00              0       시범경기       NaN
# 4    0 days 14:00:00 0 days 17:00:00              1       시범경기       NaN
# ...              ...             ...            ...        ...       ...
# 3672 0 days 19:00:00 0 days 21:00:00              0       정규시즌       NaN
# 3673 0 days 19:00:00 0 days 21:00:00              1       정규시즌       NaN
# 3674 0 days 13:57:00 0 days 15:57:00              1       정규시즌       NaN
# 3675 0 days 16:00:00 0 days 18:00:00              1       정규시즌       NaN
# 3676 0 days 19:00:00 0 days 21:00:00              1       정규시즌       NaN
#
# [3677 rows x 11 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3677 entries, 0 to 3676
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   game_id        3677 non-null   int64
#  1   stadium_code   3677 non-null   object
#  2   sports_type    3677 non-null   object
#  3   game_date      3677 non-null   datetime64[ns]
#  4   day_of_week    3677 non-null   object
#  5   is_holiday     0 non-null      object
#  6   start_time     3677 non-null   timedelta64[ns]
#  7   end_time       3677 non-null   timedelta64[ns]
#  8   home_team_win  3677 non-null   int64
#  9   match_type     3656 non-null   object
#  10  audience       1609 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(5), timedelta64[ns](2)
# memory usage: 316.1+ KB
# C:\Users\stagv\AppData\Local\Temp\ipykernel_33012\2376585274.py:20: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   sports_game_with_audience_df['audience'] = sports_game_with_audience_df['audience'].combine_first(sports_game_with_audience_df['audience_temp_kbo'])

# %%
# 축구 관중수 병합
df_klg_audience_prepared = df_klg_audience.copy()
df_klg_audience_prepared['date_klg'] = pd.to_datetime(df_klg_audience_prepared['일자'])

# 관중수 컬럼명을 임시로 변경 (충돌 방지)
df_klg_audience_prepared.rename(columns={'관중수':'audience_temp_klg'}, inplace=True)
# KBO 데이터 병합
sports_game_with_audience_df = sports_game_with_audience_df.merge(
    df_klg_audience_prepared[['stadium_code', 'date_klg', 'audience_temp_klg']],
    left_on=['stadium_code', 'game_date'],
    right_on=['stadium_code', 'date_klg'],
    how='left'
)

# 'audience' 컬럼 업데이트 및 임시 컬럼 삭제
sports_game_with_audience_df['audience'] = sports_game_with_audience_df['audience'].combine_first(sports_game_with_audience_df['audience_temp_klg'])
sports_game_with_audience_df.drop(columns=['date_klg', 'audience_temp_klg'], inplace=True, errors='ignore')

print("--- KLG 병합 후 ---")
print(sports_game_with_audience_df)
sports_game_with_audience_df.info()
print("\n")
# Out:
# --- KLG 병합 후 ---
#       game_id stadium_code sports_type  game_date day_of_week is_holiday  \
# 0           1         DJ02          야구 2023-03-13           월       None
# 1           2         SO04          야구 2023-03-13           월       None
# 2           3         CW01          야구 2023-03-13           월       None
# 3           4         BS02          야구 2023-03-13           월       None
# 4           5         DG03          야구 2023-03-13           월       None
# ...       ...          ...         ...        ...         ...        ...
# 3672     3627         HS01        여자배구 2024-12-26           목       None
# 3673     3628         HS02        여자배구 2024-12-27           금       None
# 3674     3629         IC04        여자배구 2024-12-28           토       None
# 3675     3630         HS01        여자배구 2024-12-29           일       None
# 3676     3631         DJ04        여자배구 2024-12-31           화       None
#
#           start_time        end_time  home_team_win match_type  audience
# 0    0 days 14:00:00 0 days 17:00:00              1       시범경기       NaN
# 1    0 days 14:00:00 0 days 17:00:00              0       시범경기       NaN
# 2    0 days 14:00:00 0 days 17:00:00              0       시범경기       NaN
# 3    0 days 14:00:00 0 days 17:00:00              0       시범경기       NaN
# 4    0 days 14:00:00 0 days 17:00:00              1       시범경기       NaN
# ...              ...             ...            ...        ...       ...
# 3672 0 days 19:00:00 0 days 21:00:00              0       정규시즌       NaN
# 3673 0 days 19:00:00 0 days 21:00:00              1       정규시즌       NaN
# 3674 0 days 13:57:00 0 days 15:57:00              1       정규시즌       NaN
# 3675 0 days 16:00:00 0 days 18:00:00              1       정규시즌       NaN
# 3676 0 days 19:00:00 0 days 21:00:00              1       정규시즌       NaN
#
# [3677 rows x 11 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3677 entries, 0 to 3676
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   game_id        3677 non-null   int64
#  1   stadium_code   3677 non-null   object
#  2   sports_type    3677 non-null   object
#  3   game_date      3677 non-null   datetime64[ns]
#  4   day_of_week    3677 non-null   object
#  5   is_holiday     0 non-null      object
#  6   start_time     3677 non-null   timedelta64[ns]
#  7   end_time       3677 non-null   timedelta64[ns]
#  8   home_team_win  3677 non-null   int64
#  9   match_type     3656 non-null   object
#  10  audience       2065 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(5), timedelta64[ns](2)
# memory usage: 316.1+ KB

# %%
# 배구 관중수 병합
df_vlg_audience_prepared = df_vlg_audience.copy()
df_vlg_audience_prepared['date_vlg'] = pd.to_datetime(df_vlg_audience_prepared['gDate'])

# 관중수 컬럼명을 임시로 변경 (충돌 방지)
df_vlg_audience_prepared.rename(columns={'spectators':'audience_temp_vlg'}, inplace=True)
# KBO 데이터 병합
sports_game_with_audience_df = sports_game_with_audience_df.merge(
    df_vlg_audience_prepared[['stadium_code', 'date_vlg', 'audience_temp_vlg']],
    left_on=['stadium_code', 'game_date'],
    right_on=['stadium_code', 'date_vlg'],
    how='left'
)

# 'audience' 컬럼 업데이트 및 임시 컬럼 삭제
sports_game_with_audience_df['audience'] = sports_game_with_audience_df['audience'].combine_first(sports_game_with_audience_df['audience_temp_vlg'])
sports_game_with_audience_df.drop(columns=['date_vlg', 'audience_temp_vlg'], inplace=True, errors='ignore')

print("--- VLG 병합 후 ---")
print(sports_game_with_audience_df)
sports_game_with_audience_df.info()
print("\n")
# Out:
# --- VLG 병합 후 ---
#       game_id stadium_code sports_type  game_date day_of_week is_holiday  \
# 0           1         DJ02          야구 2023-03-13           월       None
# 1           2         SO04          야구 2023-03-13           월       None
# 2           3         CW01          야구 2023-03-13           월       None
# 3           4         BS02          야구 2023-03-13           월       None
# 4           5         DG03          야구 2023-03-13           월       None
# ...       ...          ...         ...        ...         ...        ...
# 3672     3627         HS01        여자배구 2024-12-26           목       None
# 3673     3628         HS02        여자배구 2024-12-27           금       None
# 3674     3629         IC04        여자배구 2024-12-28           토       None
# 3675     3630         HS01        여자배구 2024-12-29           일       None
# 3676     3631         DJ04        여자배구 2024-12-31           화       None
#
#           start_time        end_time  home_team_win match_type  audience
# 0    0 days 14:00:00 0 days 17:00:00              1       시범경기       NaN
# 1    0 days 14:00:00 0 days 17:00:00              0       시범경기       NaN
# 2    0 days 14:00:00 0 days 17:00:00              0       시범경기       NaN
# 3    0 days 14:00:00 0 days 17:00:00              0       시범경기       NaN
# 4    0 days 14:00:00 0 days 17:00:00              1       시범경기       NaN
# ...              ...             ...            ...        ...       ...
# 3672 0 days 19:00:00 0 days 21:00:00              0       정규시즌    1626.0
# 3673 0 days 19:00:00 0 days 21:00:00              1       정규시즌    1643.0
# 3674 0 days 13:57:00 0 days 15:57:00              1       정규시즌    4968.0
# 3675 0 days 16:00:00 0 days 18:00:00              1       정규시즌    2290.0
# 3676 0 days 19:00:00 0 days 21:00:00              1       정규시즌    2335.0
#
# [3677 rows x 11 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3677 entries, 0 to 3676
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   game_id        3677 non-null   int64
#  1   stadium_code   3677 non-null   object
#  2   sports_type    3677 non-null   object
#  3   game_date      3677 non-null   datetime64[ns]
#  4   day_of_week    3677 non-null   object
#  5   is_holiday     0 non-null      object
#  6   start_time     3677 non-null   timedelta64[ns]
#  7   end_time       3677 non-null   timedelta64[ns]
#  8   home_team_win  3677 non-null   int64
#  9   match_type     3656 non-null   object
#  10  audience       2599 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(5), timedelta64[ns](2)
# memory usage: 316.1+ KB

# %% [markdown]
# ### 농구 관중수도 병합해보려 했으나 보유한 데이터와 실제 데이터의 갯수가 맞지않아 경기기록과 일치가 불가하여 드랍

# %%
# 파일로 출력
sports_game_with_audience_df.to_csv('./dataset/sports_game_with_audience.csv')

# %%
# 데이터 베이스에 삽입

from sqlalchemy import create_engine, text, Table, MetaData, update
from sqlalchemy.exc import SQLAlchemyError
import pandas as pd
import numpy as np

with open("./db_config.json", "r") as f:
    config = json.load(f)
    
DB_USER = config["DB_USER"]
DB_PASSWORD = config["DB_PASSWORD"]
DB_HOST = config["DB_HOST"]
DB_NAME = config["DB_NAME"]
DB_PORT = config["DB_PORT"]

# SQLAlchemy 엔진 생성
engine_url = f"mysql+pymysql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"

engine = create_engine(engine_url)
metadata = MetaData()

# sports_game 테이블 객체 로드 (테이블이 DB에 이미 존재해야 함)
# autoload_with를 사용하면 DB에서 테이블 구조를 읽어옴
try:
    sports_game_table = Table('sports_game', metadata, autoload_with=engine)
except SQLAlchemyError as e:
    print(f"Error loading table 'sports_game': {e}")
    print("Please ensure the table exists in the database and connection details are correct.")
    exit()

# --- 데이터 업데이트 ---
updated_rows_count = 0
skipped_due_to_nan_audience = 0 # audience가 NaN/NA인 경우 업데이트를 건너뛸지 여부
sports_game_with_audience_df = pd.read_csv('./dataset/sports_game_with_audience.csv')

# 트랜잭션 시작
with engine.connect() as connection:
    with connection.begin(): # 트랜잭션 시작
        for index, row in sports_game_with_audience_df.iterrows():
            stadium_code_val = row['stadium_code']
            sports_type_val = row['sports_type']
            game_date_val = row['game_date'] # Pandas Timestamp 객체
            audience_val = row['audience']

            # audience 값이 pd.NA 또는 np.nan 인 경우 SQL NULL로 처리됨
            # 만약 audience 값이 유효한 숫자일 때만 업데이트하고 싶다면, 아래 주석을 해제
            if pd.isna(audience_val):
                skipped_due_to_nan_audience += 1
                print(f"Skipping row {index} due to NaN audience: {stadium_code_val}, {sports_type_val}, {game_date_val}")
                continue
            
            # audience_val이 pd.NA면 SQLAlchemy가 알아서 NULL로 변환해줌
            # 만약 DB의 audience 컬럼이 INT이고, DataFrame의 audience가 float (np.nan 포함)이라면,
            # 유효한 숫자는 정수로 변환해주는 것이 좋음. pd.NA는 None으로 취급.
            if pd.notna(audience_val) and isinstance(audience_val, (float, np.floating)): # np.nan은 float임
                 audience_to_set = int(audience_val)
            elif pd.isna(audience_val): # pd.NA 또는 np.nan
                 audience_to_set = None # SQL NULL
            else: # 정수형 pd.NA가 아닌 경우 (이미 Int64로 변환되었거나 문자열 등)
                 audience_to_set = audience_val # int(audience_val) 하거나 그대로 둠

            try:
                stmt = (
                    update(sports_game_table)
                    .where(sports_game_table.c.stadium_code == stadium_code_val)
                    .where(sports_game_table.c.sports_type == sports_type_val)
                    .where(sports_game_table.c.game_date == game_date_val) # game_date가 DB에서 DATE 타입이면 .date() 필요할 수 있음
                    .values(audience=audience_to_set)
                )
                result = connection.execute(stmt)
                if result.rowcount > 0:
                    updated_rows_count += result.rowcount
                # else:
                #     print(f"No matching row found in DB for: {stadium_code_val}, {sports_type_val}, {game_date_val.date()}")

            except SQLAlchemyError as e:
                print(f"Error updating row {index} ({stadium_code_val}, {sports_type_val}, {game_date_val}): {e}")
            except Exception as ex: # Pandas Timestamp 관련 오류 등
                print(f"General error processing row {index} ({stadium_code_val}, {sports_type_val}, {game_date_val}): {ex}")


    # 트랜잭션이 성공적으로 끝나면 여기서 자동으로 commit됨
    # 오류 발생 시 자동으로 rollback됨

print(f"--- 업데이트 완료 ---")
print(f"총 {updated_rows_count} 개의 행의 audience 정보가 DB에 반영(또는 시도)되었습니다.")
if skipped_due_to_nan_audience > 0:
    print(f"{skipped_due_to_nan_audience} 개의 행은 audience 값이 NaN/NA 여서 건너뛰었습니다.")
# Out:
# Skipping row 0 due to NaN audience: DJ02, 야구, 2023-03-13
# Skipping row 1 due to NaN audience: SO04, 야구, 2023-03-13
# Skipping row 2 due to NaN audience: CW01, 야구, 2023-03-13
# Skipping row 3 due to NaN audience: BS02, 야구, 2023-03-13
# Skipping row 4 due to NaN audience: DG03, 야구, 2023-03-13
# Skipping row 5 due to NaN audience: DJ02, 야구, 2023-03-14
# Skipping row 6 due to NaN audience: SO04, 야구, 2023-03-14
# Skipping row 7 due to NaN audience: CW01, 야구, 2023-03-14
# Skipping row 8 due to NaN audience: BS02, 야구, 2023-03-14
# Skipping row 9 due to NaN audience: DG03, 야구, 2023-03-14
# Skipping row 10 due to NaN audience: SO04, 야구, 2023-03-15
# Skipping row 11 due to NaN audience: DJ02, 야구, 2023-03-15
# Skipping row 12 due to NaN audience: DG03, 야구, 2023-03-15
# Skipping row 13 due to NaN audience: CW01, 야구, 2023-03-15
# Skipping row 14 due to NaN audience: BS02, 야구, 2023-03-15
# Skipping row 15 due to NaN audience: SO04, 야구, 2023-03-16
# Skipping row 16 due to NaN audience: DJ02, 야구, 2023-03-16
# Skipping row 17 due to NaN audience: DG03, 야구, 2023-03-16
# Skipping row 18 due to NaN audience: CW01, 야구, 2023-03-16
# Skipping row 19 due to NaN audience: BS02, 야구, 2023-03-16
# Skipping row 20 due to NaN audience: DG03, 야구, 2023-03-18
# Skipping row 21 due to NaN audience: BS02, 야구, 2023-03-18
# Skipping row 22 due to NaN audience: GJ02, 야구, 2023-03-18
# Skipping row 23 due to NaN audience: CW01, 야구, 2023-03-18
# Skipping row 24 due to NaN audience: DJ02, 야구, 2023-03-18
# Skipping row 25 due to NaN audience: DG03, 야구, 2023-03-19
# Skipping row 26 due to NaN audience: BS02, 야구, 2023-03-19
# Skipping row 27 due to NaN audience: GJ02, 야구, 2023-03-19
# Skipping row 28 due to NaN audience: CW01, 야구, 2023-03-19
# Skipping row 29 due to NaN audience: DJ02, 야구, 2023-03-19
# Skipping row 30 due to NaN audience: GJ02, 야구, 2023-03-20
# Skipping row 31 due to NaN audience: DG03, 야구, 2023-03-20
# Skipping row 32 due to NaN audience: SU03, 야구, 2023-03-20
# Skipping row 33 due to NaN audience: DJ02, 야구, 2023-03-20
# Skipping row 34 due to NaN audience: CW01, 야구, 2023-03-20
# Skipping row 35 due to NaN audience: GJ02, 야구, 2023-03-21
# Skipping row 36 due to NaN audience: DG03, 야구, 2023-03-21
# Skipping row 37 due to NaN audience: SU03, 야구, 2023-03-21
# Skipping row 38 due to NaN audience: DJ02, 야구, 2023-03-21
# Skipping row 39 due to NaN audience: CW01, 야구, 2023-03-21
# Skipping row 40 due to NaN audience: SU03, 야구, 2023-03-23
# Skipping row 41 due to NaN audience: CW01, 야구, 2023-03-23
# Skipping row 42 due to NaN audience: DJ02, 야구, 2023-03-23
# Skipping row 43 due to NaN audience: GJ02, 야구, 2023-03-23
# Skipping row 44 due to NaN audience: SO04, 야구, 2023-03-23
# Skipping row 45 due to NaN audience: SU03, 야구, 2023-03-24
# Skipping row 46 due to NaN audience: CW01, 야구, 2023-03-24
# Skipping row 47 due to NaN audience: DJ02, 야구, 2023-03-24
# Skipping row 48 due to NaN audience: GJ02, 야구, 2023-03-24
# Skipping row 49 due to NaN audience: SO04, 야구, 2023-03-24
# Skipping row 50 due to NaN audience: SO04, 야구, 2023-03-25
# Skipping row 51 due to NaN audience: SU03, 야구, 2023-03-25
# Skipping row 52 due to NaN audience: SO05, 야구, 2023-03-25
# Skipping row 53 due to NaN audience: BS02, 야구, 2023-03-25
# Skipping row 54 due to NaN audience: GJ02, 야구, 2023-03-25
# Skipping row 55 due to NaN audience: BS02, 야구, 2023-03-26
# Skipping row 56 due to NaN audience: SO04, 야구, 2023-03-26
# Skipping row 57 due to NaN audience: GJ02, 야구, 2023-03-26
# Skipping row 58 due to NaN audience: SU03, 야구, 2023-03-26
# Skipping row 59 due to NaN audience: SO05, 야구, 2023-03-26
# Skipping row 60 due to NaN audience: SU03, 야구, 2023-03-27
# Skipping row 61 due to NaN audience: SO04, 야구, 2023-03-27
# Skipping row 62 due to NaN audience: SO05, 야구, 2023-03-27
# Skipping row 63 due to NaN audience: DG03, 야구, 2023-03-27
# Skipping row 64 due to NaN audience: BS02, 야구, 2023-03-27
# Skipping row 65 due to NaN audience: DG03, 야구, 2023-03-28
# Skipping row 66 due to NaN audience: BS02, 야구, 2023-03-28
# Skipping row 67 due to NaN audience: SU03, 야구, 2023-03-28
# Skipping row 68 due to NaN audience: SO04, 야구, 2023-03-28
# Skipping row 69 due to NaN audience: SO05, 야구, 2023-03-28
# Skipping row 81 due to NaN audience: SU03, 야구, 2023-04-04
# Skipping row 85 due to NaN audience: DG03, 야구, 2023-04-05
# Skipping row 86 due to NaN audience: SU03, 야구, 2023-04-05
# Skipping row 88 due to NaN audience: IC02, 야구, 2023-04-05
# Skipping row 91 due to NaN audience: SU03, 야구, 2023-04-06
# Skipping row 93 due to NaN audience: IC02, 야구, 2023-04-06
# Skipping row 119 due to NaN audience: SO05, 야구, 2023-04-12
# Skipping row 170 due to NaN audience: BS02, 야구, 2023-04-25
# Skipping row 173 due to NaN audience: DG03, 야구, 2023-04-25
# Skipping row 194 due to NaN audience: BS02, 야구, 2023-04-29
# Skipping row 212 due to NaN audience: CW01, 야구, 2023-05-04
# Skipping row 213 due to NaN audience: GJ02, 야구, 2023-05-04
# Skipping row 215 due to NaN audience: CW01, 야구, 2023-05-05
# Skipping row 216 due to NaN audience: DJ02, 야구, 2023-05-05
# Skipping row 217 due to NaN audience: SO05, 야구, 2023-05-05
# Skipping row 219 due to NaN audience: BS02, 야구, 2023-05-05
# Skipping row 220 due to NaN audience: SO05, 야구, 2023-05-06
# Skipping row 221 due to NaN audience: CW01, 야구, 2023-05-06
# Skipping row 222 due to NaN audience: DJ02, 야구, 2023-05-06
# Skipping row 224 due to NaN audience: BS02, 야구, 2023-05-06
# Skipping row 225 due to NaN audience: CW01, 야구, 2023-05-07
# Skipping row 229 due to NaN audience: BS02, 야구, 2023-05-07
# Skipping row 270 due to NaN audience: DG03, 야구, 2023-05-18
# Skipping row 274 due to NaN audience: CW01, 야구, 2023-05-18
# Skipping row 314 due to NaN audience: SO05, 야구, 2023-05-27
# Skipping row 315 due to NaN audience: CW01, 야구, 2023-05-28
# Skipping row 319 due to NaN audience: SO05, 야구, 2023-05-28
# Skipping row 330 due to NaN audience: GJ02, 야구, 2023-06-01
# Skipping row 332 due to NaN audience: CW01, 야구, 2023-06-01
# Skipping row 436 due to NaN audience: CW01, 야구, 2023-06-25
# Skipping row 437 due to NaN audience: GJ02, 야구, 2023-06-25
# Skipping row 450 due to NaN audience: DJ02, 야구, 2023-06-29
# Skipping row 451 due to NaN audience: IC02, 야구, 2023-06-29
# Skipping row 452 due to NaN audience: SO05, 야구, 2023-06-29
# Skipping row 453 due to NaN audience: BS02, 야구, 2023-06-29
# Skipping row 454 due to NaN audience: GJ02, 야구, 2023-06-29
# Skipping row 470 due to NaN audience: IC02, 야구, 2023-07-04
# Skipping row 471 due to NaN audience: SO05, 야구, 2023-07-04
# Skipping row 472 due to NaN audience: DJ02, 야구, 2023-07-04
# Skipping row 486 due to NaN audience: BS02, 야구, 2023-07-07
# Skipping row 487 due to NaN audience: DJ02, 야구, 2023-07-07
# Skipping row 488 due to NaN audience: CW01, 야구, 2023-07-07
# Skipping row 500 due to NaN audience: SO05, 야구, 2023-07-11
# Skipping row 502 due to NaN audience: CW01, 야구, 2023-07-11
# Skipping row 503 due to NaN audience: IC02, 야구, 2023-07-11
# Skipping row 504 due to NaN audience: GJ02, 야구, 2023-07-11
# Skipping row 510 due to NaN audience: SO05, 야구, 2023-07-13
# Skipping row 513 due to NaN audience: IC02, 야구, 2023-07-13
# Skipping row 515 due to NaN audience: BS02, 야구, 2023-07-15
# Skipping row 523 due to NaN audience: GJ02, 야구, 2023-07-22
# Skipping row 524 due to NaN audience: SO05, 야구, 2023-07-22
# Skipping row 527 due to NaN audience: DJ02, 야구, 2023-07-23
# Skipping row 528 due to NaN audience: GJ02, 야구, 2023-07-23
# Skipping row 529 due to NaN audience: SO05, 야구, 2023-07-23
# Skipping row 592 due to NaN audience: GJ02, 야구, 2023-08-08
# Skipping row 601 due to NaN audience: SU03, 야구, 2023-08-10
# Skipping row 602 due to NaN audience: GJ02, 야구, 2023-08-10
# Skipping row 604 due to NaN audience: IC02, 야구, 2023-08-10
# Skipping row 605 due to NaN audience: SO05, 야구, 2023-08-10
# Skipping row 640 due to NaN audience: SO05, 야구, 2023-08-18
# Skipping row 652 due to NaN audience: SO05, 야구, 2023-08-22
# Skipping row 653 due to NaN audience: IC02, 야구, 2023-08-22
# Skipping row 656 due to NaN audience: SU03, 야구, 2023-08-23
# Skipping row 657 due to NaN audience: SO05, 야구, 2023-08-23
# Skipping row 658 due to NaN audience: IC02, 야구, 2023-08-23
# Skipping row 660 due to NaN audience: DJ02, 야구, 2023-08-23
# Skipping row 665 due to NaN audience: DJ02, 야구, 2023-08-24
# Skipping row 681 due to NaN audience: DJ02, 야구, 2023-08-29
# Skipping row 682 due to NaN audience: GJ02, 야구, 2023-08-29
# Skipping row 683 due to NaN audience: SO05, 야구, 2023-08-29
# Skipping row 684 due to NaN audience: SU03, 야구, 2023-08-29
# Skipping row 685 due to NaN audience: IC02, 야구, 2023-08-29
# Skipping row 686 due to NaN audience: DJ02, 야구, 2023-08-30
# Skipping row 687 due to NaN audience: GJ02, 야구, 2023-08-30
# Skipping row 688 due to NaN audience: SO05, 야구, 2023-08-30
# Skipping row 689 due to NaN audience: SU03, 야구, 2023-08-30
# Skipping row 700 due to NaN audience: BS02, 야구, 2023-09-01
# Skipping row 705 due to NaN audience: BS02, 야구, 2023-09-02
# Skipping row 712 due to NaN audience: SO05, 야구, 2023-09-05
# Skipping row 760 due to NaN audience: SO05, 야구, 2023-09-13
# Skipping row 762 due to NaN audience: CW01, 야구, 2023-09-14
# Skipping row 763 due to NaN audience: GJ02, 야구, 2023-09-14
# Skipping row 769 due to NaN audience: DJ02, 야구, 2023-09-16
# Skipping row 770 due to NaN audience: GJ02, 야구, 2023-09-16
# Skipping row 772 due to NaN audience: CW01, 야구, 2023-09-16
# Skipping row 773 due to NaN audience: BS02, 야구, 2023-09-16
# Skipping row 791 due to NaN audience: SU03, 야구, 2023-09-20
# Skipping row 792 due to NaN audience: DJ02, 야구, 2023-09-20
# Skipping row 793 due to NaN audience: SO05, 야구, 2023-09-20
# Skipping row 794 due to NaN audience: DG03, 야구, 2023-09-20
# Skipping row 795 due to NaN audience: GJ02, 야구, 2023-09-20
# Skipping row 815 due to NaN audience: SO05, 야구, 2023-09-26
# Skipping row 816 due to NaN audience: IC02, 야구, 2023-09-26
# Skipping row 817 due to NaN audience: DJ02, 야구, 2023-09-26
# Skipping row 908 due to NaN audience: CW01, 야구, 2023-10-19
# Skipping row 909 due to NaN audience: IC02, 야구, 2023-10-22
# Skipping row 910 due to NaN audience: IC02, 야구, 2023-10-23
# Skipping row 911 due to NaN audience: CW01, 야구, 2023-10-25
# Skipping row 912 due to NaN audience: SU03, 야구, 2023-10-30
# Skipping row 913 due to NaN audience: SU03, 야구, 2023-10-31
# Skipping row 914 due to NaN audience: CW01, 야구, 2023-11-02
# Skipping row 915 due to NaN audience: CW01, 야구, 2023-11-03
# Skipping row 916 due to NaN audience: SU03, 야구, 2023-11-05
# Skipping row 917 due to NaN audience: SO05, 야구, 2023-11-07
# Skipping row 918 due to NaN audience: SO05, 야구, 2023-11-08
# Skipping row 919 due to NaN audience: SU03, 야구, 2023-11-10
# Skipping row 920 due to NaN audience: SU03, 야구, 2023-11-11
# Skipping row 921 due to NaN audience: SO05, 야구, 2023-11-13
# Skipping row 922 due to NaN audience: CW01, 야구, 2024-03-09
# Skipping row 923 due to NaN audience: SU03, 야구, 2024-03-09
# Skipping row 924 due to NaN audience: BS02, 야구, 2024-03-09
# Skipping row 925 due to NaN audience: DJ02, 야구, 2024-03-09
# Skipping row 926 due to NaN audience: IH01, 야구, 2024-03-09
# Skipping row 927 due to NaN audience: CW01, 야구, 2024-03-10
# Skipping row 928 due to NaN audience: SU03, 야구, 2024-03-10
# Skipping row 929 due to NaN audience: BS02, 야구, 2024-03-10
# Skipping row 930 due to NaN audience: DJ02, 야구, 2024-03-10
# Skipping row 931 due to NaN audience: IH01, 야구, 2024-03-10
# Skipping row 932 due to NaN audience: DJ02, 야구, 2024-03-11
# Skipping row 933 due to NaN audience: DG03, 야구, 2024-03-11
# Skipping row 934 due to NaN audience: BS02, 야구, 2024-03-11
# Skipping row 935 due to NaN audience: SU03, 야구, 2024-03-11
# Skipping row 936 due to NaN audience: CW01, 야구, 2024-03-11
# Skipping row 937 due to NaN audience: DJ02, 야구, 2024-03-12
# Skipping row 938 due to NaN audience: DG03, 야구, 2024-03-12
# Skipping row 939 due to NaN audience: BS02, 야구, 2024-03-12
# Skipping row 940 due to NaN audience: SU03, 야구, 2024-03-12
# Skipping row 941 due to NaN audience: CW01, 야구, 2024-03-12
# Skipping row 942 due to NaN audience: SO05, 야구, 2024-03-14
# Skipping row 943 due to NaN audience: DJ02, 야구, 2024-03-14
# Skipping row 944 due to NaN audience: CW01, 야구, 2024-03-14
# Skipping row 945 due to NaN audience: DG03, 야구, 2024-03-14
# Skipping row 946 due to NaN audience: IC02, 야구, 2024-03-14
# Skipping row 947 due to NaN audience: SO05, 야구, 2024-03-15
# Skipping row 948 due to NaN audience: DJ02, 야구, 2024-03-15
# Skipping row 949 due to NaN audience: CW01, 야구, 2024-03-15
# Skipping row 950 due to NaN audience: DG03, 야구, 2024-03-15
# Skipping row 951 due to NaN audience: IC02, 야구, 2024-03-15
# Skipping row 952 due to NaN audience: BS02, 야구, 2024-03-16
# Skipping row 953 due to NaN audience: GJ02, 야구, 2024-03-16
# Skipping row 954 due to NaN audience: DG03, 야구, 2024-03-16
# Skipping row 955 due to NaN audience: IC02, 야구, 2024-03-16
# Skipping row 956 due to NaN audience: SO05, 야구, 2024-03-16
# Skipping row 957 due to NaN audience: BS02, 야구, 2024-03-17
# Skipping row 958 due to NaN audience: GJ02, 야구, 2024-03-17
# Skipping row 959 due to NaN audience: DG03, 야구, 2024-03-17
# Skipping row 960 due to NaN audience: IC02, 야구, 2024-03-17
# Skipping row 961 due to NaN audience: SU03, 야구, 2024-03-18
# Skipping row 962 due to NaN audience: DJ02, 야구, 2024-03-18
# Skipping row 963 due to NaN audience: IC02, 야구, 2024-03-18
# Skipping row 964 due to NaN audience: GJ02, 야구, 2024-03-18
# Skipping row 965 due to NaN audience: SU03, 야구, 2024-03-19
# Skipping row 966 due to NaN audience: IC02, 야구, 2024-03-19
# Skipping row 967 due to NaN audience: DJ02, 야구, 2024-03-19
# Skipping row 968 due to NaN audience: GJ02, 야구, 2024-03-19
# Skipping row 969 due to NaN audience: SO05, 야구, 2024-03-19
# Skipping row 979 due to NaN audience: GJ02, 야구, 2024-03-24
# Skipping row 991 due to NaN audience: GJ02, 야구, 2024-03-28
# Skipping row 994 due to NaN audience: CW01, 야구, 2024-03-28
# Skipping row 1016 due to NaN audience: DJ02, 야구, 2024-04-03
# Skipping row 1019 due to NaN audience: DG03, 야구, 2024-04-03
# Skipping row 1080 due to NaN audience: CW01, 야구, 2024-04-18
# Skipping row 1090 due to NaN audience: BS02, 야구, 2024-04-20
# Skipping row 1091 due to NaN audience: IC02, 야구, 2024-04-20
# Skipping row 1094 due to NaN audience: SO05, 야구, 2024-04-20
# Skipping row 1113 due to NaN audience: BS02, 야구, 2024-04-23
# Skipping row 1164 due to NaN audience: GJ02, 야구, 2024-05-05
# Skipping row 1165 due to NaN audience: DG03, 야구, 2024-05-05
# Skipping row 1166 due to NaN audience: IC02, 야구, 2024-05-05
# Skipping row 1167 due to NaN audience: SO05, 야구, 2024-05-05
# Skipping row 1168 due to NaN audience: SU03, 야구, 2024-05-05
# Skipping row 1169 due to NaN audience: BS02, 야구, 2024-05-07
# Skipping row 1170 due to NaN audience: DG03, 야구, 2024-05-07
# Skipping row 1171 due to NaN audience: SU03, 야구, 2024-05-07
# Skipping row 1190 due to NaN audience: SO05, 야구, 2024-05-11
# Skipping row 1192 due to NaN audience: GJ02, 야구, 2024-05-11
# Skipping row 1210 due to NaN audience: SU03, 야구, 2024-05-15
# Skipping row 1213 due to NaN audience: IC02, 야구, 2024-05-15
# Skipping row 1214 due to NaN audience: SO05, 야구, 2024-05-15
# Skipping row 1260 due to NaN audience: IC02, 야구, 2024-05-26
# Skipping row 1264 due to NaN audience: SU03, 야구, 2024-05-26
# Skipping row 1318 due to NaN audience: BS02, 야구, 2024-06-08
# Skipping row 1378 due to NaN audience: GJ02, 야구, 2024-06-22
# Skipping row 1379 due to NaN audience: SO05, 야구, 2024-06-22
# Skipping row 1382 due to NaN audience: DG03, 야구, 2024-06-22
# Skipping row 1417 due to NaN audience: BS02, 야구, 2024-06-29
# Skipping row 1418 due to NaN audience: CW01, 야구, 2024-06-29
# Skipping row 1420 due to NaN audience: SU03, 야구, 2024-06-29
# Skipping row 1421 due to NaN audience: GJ02, 야구, 2024-06-29
# Skipping row 1422 due to NaN audience: BS02, 야구, 2024-06-30
# Skipping row 1424 due to NaN audience: GJ02, 야구, 2024-06-30
# Skipping row 1427 due to NaN audience: BS02, 야구, 2024-06-30
# Skipping row 1430 due to NaN audience: GJ02, 야구, 2024-06-30
# Skipping row 1436 due to NaN audience: SO05, 야구, 2024-07-02
# Skipping row 1437 due to NaN audience: CW01, 야구, 2024-07-02
# Skipping row 1448 due to NaN audience: IC02, 야구, 2024-07-06
# Skipping row 1452 due to NaN audience: DG03, 야구, 2024-07-09
# Skipping row 1453 due to NaN audience: SU03, 야구, 2024-07-09
# Skipping row 1474 due to NaN audience: BS02, 야구, 2024-07-14
# Skipping row 1478 due to NaN audience: CW01, 야구, 2024-07-14
# Skipping row 1479 due to NaN audience: CW01, 야구, 2024-07-16
# Skipping row 1482 due to NaN audience: SO05, 야구, 2024-07-16
# Skipping row 1483 due to NaN audience: GJ02, 야구, 2024-07-16
# Skipping row 1492 due to NaN audience: SO05, 야구, 2024-07-18
# Skipping row 1501 due to NaN audience: SU03, 야구, 2024-07-20
# Skipping row 1502 due to NaN audience: SO05, 야구, 2024-07-20
# Skipping row 1503 due to NaN audience: IC02, 야구, 2024-07-20
# Skipping row 1511 due to NaN audience: SU03, 야구, 2024-07-23
# Skipping row 1514 due to NaN audience: BS02, 야구, 2024-07-24
# Skipping row 1522 due to NaN audience: DJ02, 야구, 2024-07-25
# Skipping row 1524 due to NaN audience: SO05, 야구, 2024-07-26
# Skipping row 1529 due to NaN audience: SO05, 야구, 2024-07-27
# Skipping row 1556 due to NaN audience: US03, 야구, 2024-08-02
# Skipping row 1560 due to NaN audience: CW01, 야구, 2024-08-03
# Skipping row 1564 due to NaN audience: DJ02, 야구, 2024-08-04
# Skipping row 1566 due to NaN audience: US03, 야구, 2024-08-04
# Skipping row 1568 due to NaN audience: SO05, 야구, 2024-08-04
# Skipping row 1582 due to NaN audience: BS02, 야구, 2024-08-08
# Skipping row 1592 due to NaN audience: GJ02, 야구, 2024-08-10
# Skipping row 1602 due to NaN audience: SO05, 야구, 2024-08-13
# Skipping row 1608 due to NaN audience: CW01, 야구, 2024-08-14
# Skipping row 1629 due to NaN audience: GJ02, 야구, 2024-08-20
# Skipping row 1640 due to NaN audience: CJ01, 야구, 2024-08-22
# Skipping row 1641 due to NaN audience: PH02, 야구, 2024-08-22
# Skipping row 1719 due to NaN audience: SO05, 야구, 2024-09-12
# Skipping row 1722 due to NaN audience: IC02, 야구, 2024-09-13
# Skipping row 1723 due to NaN audience: SO05, 야구, 2024-09-13
# Skipping row 1748 due to NaN audience: CW01, 야구, 2024-09-20
# Skipping row 1749 due to NaN audience: SO05, 야구, 2024-09-20
# Skipping row 1750 due to NaN audience: IC02, 야구, 2024-09-20
# Skipping row 1753 due to NaN audience: DJ02, 야구, 2024-09-21
# Skipping row 1754 due to NaN audience: GJ02, 야구, 2024-09-21
# Skipping row 1756 due to NaN audience: DG03, 야구, 2024-09-21
# Skipping row 1763 due to NaN audience: GJ02, 야구, 2024-09-22
# Skipping row 1791 due to NaN audience: SU03, 야구, 2024-10-01
# Skipping row 1792 due to NaN audience: SO05, 야구, 2024-10-02
# Skipping row 1793 due to NaN audience: SO05, 야구, 2024-10-03
# Skipping row 1794 due to NaN audience: SO05, 야구, 2024-10-05
# Skipping row 1795 due to NaN audience: SO05, 야구, 2024-10-06
# Skipping row 1796 due to NaN audience: SU03, 야구, 2024-10-08
# Skipping row 1797 due to NaN audience: SU03, 야구, 2024-10-09
# Skipping row 1798 due to NaN audience: SO05, 야구, 2024-10-11
# Skipping row 1799 due to NaN audience: DG03, 야구, 2024-10-13
# Skipping row 1800 due to NaN audience: DG03, 야구, 2024-10-14
# Skipping row 1801 due to NaN audience: DG03, 야구, 2024-10-15
# Skipping row 1802 due to NaN audience: SO05, 야구, 2024-10-17
# Skipping row 1803 due to NaN audience: SO05, 야구, 2024-10-18
# Skipping row 1804 due to NaN audience: SO05, 야구, 2024-10-19
# Skipping row 1805 due to NaN audience: GJ02, 야구, 2024-10-21
# Skipping row 1806 due to NaN audience: GJ02, 야구, 2024-10-22
# Skipping row 1807 due to NaN audience: GJ02, 야구, 2024-10-23
# Skipping row 1808 due to NaN audience: DG03, 야구, 2024-10-25
# Skipping row 1809 due to NaN audience: DG03, 야구, 2024-10-26
# Skipping row 1810 due to NaN audience: GJ02, 야구, 2024-10-28
# Skipping row 1812 due to NaN audience: DG03, 야구, 2024-08-01
# Skipping row 1816 due to NaN audience: GJ02, 야구, 2024-08-02
# Skipping row 1818 due to NaN audience: SO04, 야구, 2024-08-02
# Skipping row 1819 due to NaN audience: SU03, 야구, 2024-08-02
# Skipping row 1821 due to NaN audience: SO04, 야구, 2024-08-03
# Skipping row 1822 due to NaN audience: GJ02, 야구, 2024-08-03
# Skipping row 1824 due to NaN audience: SU03, 야구, 2024-08-03
# Skipping row 1826 due to NaN audience: BS02, 야구, 2024-08-05
# Skipping row 1827 due to NaN audience: DJ02, 야구, 2024-08-05
# Skipping row 1828 due to NaN audience: SO05, 야구, 2024-08-05
# Skipping row 1829 due to NaN audience: IC02, 야구, 2024-08-05
# Skipping row 1830 due to NaN audience: CW01, 야구, 2024-08-05
# Skipping row 1832 due to NaN audience: DJ02, 야구, 2024-08-06
# Skipping row 1834 due to NaN audience: IC02, 야구, 2024-08-06
# Skipping row 1835 due to NaN audience: CW01, 야구, 2024-08-06
# Skipping row 1837 due to NaN audience: DJ02, 야구, 2024-08-07
# Skipping row 1839 due to NaN audience: IC02, 야구, 2024-08-07
# Skipping row 1840 due to NaN audience: CW01, 야구, 2024-08-07
# Skipping row 1843 due to NaN audience: BS02, 야구, 2024-08-08
# Skipping row 1844 due to NaN audience: SU03, 야구, 2024-08-08
# Skipping row 1845 due to NaN audience: CW01, 야구, 2024-08-08
# Skipping row 1847 due to NaN audience: SO04, 야구, 2024-08-09
# Skipping row 1848 due to NaN audience: BS02, 야구, 2024-08-09
# Skipping row 1850 due to NaN audience: CW01, 야구, 2024-08-09
# Skipping row 1851 due to NaN audience: SO04, 야구, 2024-08-10
# Skipping row 1853 due to NaN audience: BS02, 야구, 2024-08-10
# Skipping row 1855 due to NaN audience: CW01, 야구, 2024-08-10
# Skipping row 1856 due to NaN audience: DG03, 야구, 2024-08-12
# Skipping row 1857 due to NaN audience: SU03, 야구, 2024-08-12
# Skipping row 1858 due to NaN audience: DJ02, 야구, 2024-08-12
# Skipping row 1859 due to NaN audience: SO05, 야구, 2024-08-12
# Skipping row 1860 due to NaN audience: IC02, 야구, 2024-08-12
# Skipping row 1862 due to NaN audience: SU03, 야구, 2024-08-13
# Skipping row 1864 due to NaN audience: SO05, 야구, 2024-08-13
# Skipping row 1865 due to NaN audience: IC02, 야구, 2024-08-13
# Skipping row 1867 due to NaN audience: SU03, 야구, 2024-08-14
# Skipping row 1870 due to NaN audience: IC02, 야구, 2024-08-14
# Skipping row 1874 due to NaN audience: IC02, 야구, 2024-08-15
# Skipping row 1875 due to NaN audience: BS02, 야구, 2024-08-15
# Skipping row 1878 due to NaN audience: SO04, 야구, 2024-08-16
# Skipping row 1881 due to NaN audience: SO04, 야구, 2024-08-17
# Skipping row 1886 due to NaN audience: SO05, 야구, 2024-08-19
# Skipping row 1887 due to NaN audience: DJ02, 야구, 2024-08-19
# Skipping row 1888 due to NaN audience: SU03, 야구, 2024-08-19
# Skipping row 1889 due to NaN audience: GJ02, 야구, 2024-08-19
# Skipping row 1890 due to NaN audience: CW01, 야구, 2024-08-19
# Skipping row 1892 due to NaN audience: DJ02, 야구, 2024-08-20
# Skipping row 1894 due to NaN audience: GJ02, 야구, 2024-08-20
# Skipping row 1895 due to NaN audience: CW01, 야구, 2024-08-20
# Skipping row 1897 due to NaN audience: DJ02, 야구, 2024-08-21
# Skipping row 1900 due to NaN audience: CW01, 야구, 2024-08-21
# Skipping row 1903 due to NaN audience: CW01, 야구, 2024-08-22
# Skipping row 1904 due to NaN audience: DJ02, 야구, 2024-08-22
# Skipping row 1905 due to NaN audience: DG03, 야구, 2024-08-22
# Skipping row 1907 due to NaN audience: GJ02, 야구, 2024-08-23
# Skipping row 1909 due to NaN audience: DJ02, 야구, 2024-08-23
# Skipping row 1912 due to NaN audience: GJ02, 야구, 2024-08-24
# Skipping row 1914 due to NaN audience: DJ02, 야구, 2024-08-24
# Skipping row 1916 due to NaN audience: SO04, 야구, 2024-08-26
# Skipping row 1917 due to NaN audience: IC02, 야구, 2024-08-26
# Skipping row 1918 due to NaN audience: BS02, 야구, 2024-08-26
# Skipping row 1919 due to NaN audience: CW01, 야구, 2024-08-26
# Skipping row 1920 due to NaN audience: SO05, 야구, 2024-08-26
# Skipping row 1922 due to NaN audience: IC02, 야구, 2024-08-27
# Skipping row 1927 due to NaN audience: IC02, 야구, 2024-08-28
# Skipping row 1931 due to NaN audience: SU03, 야구, 2024-08-29
# Skipping row 1932 due to NaN audience: IC02, 야구, 2024-08-29
# Skipping row 1934 due to NaN audience: DJ02, 야구, 2024-08-29
# Skipping row 1937 due to NaN audience: IC02, 야구, 2024-08-30
# Skipping row 1938 due to NaN audience: BS02, 야구, 2024-08-30
# Skipping row 1939 due to NaN audience: DJ02, 야구, 2024-08-30
# Skipping row 1940 due to NaN audience: SO05, 야구, 2024-08-30
# Skipping row 1941 due to NaN audience: SU03, 야구, 2024-08-31
# Skipping row 1943 due to NaN audience: BS02, 야구, 2024-08-31
# Skipping row 1947 due to NaN audience: DG03, 야구, 2024-08-01
# Skipping row 1951 due to NaN audience: GJ02, 야구, 2024-08-02
# Skipping row 1953 due to NaN audience: SO04, 야구, 2024-08-02
# Skipping row 1954 due to NaN audience: SU03, 야구, 2024-08-02
# Skipping row 1956 due to NaN audience: SO04, 야구, 2024-08-03
# Skipping row 1957 due to NaN audience: GJ02, 야구, 2024-08-03
# Skipping row 1959 due to NaN audience: SU03, 야구, 2024-08-03
# Skipping row 1961 due to NaN audience: BS02, 야구, 2024-08-05
# Skipping row 1962 due to NaN audience: DJ02, 야구, 2024-08-05
# Skipping row 1963 due to NaN audience: SO05, 야구, 2024-08-05
# Skipping row 1964 due to NaN audience: IC02, 야구, 2024-08-05
# Skipping row 1965 due to NaN audience: CW01, 야구, 2024-08-05
# Skipping row 1967 due to NaN audience: DJ02, 야구, 2024-08-06
# Skipping row 1969 due to NaN audience: IC02, 야구, 2024-08-06
# Skipping row 1970 due to NaN audience: CW01, 야구, 2024-08-06
# Skipping row 1972 due to NaN audience: DJ02, 야구, 2024-08-07
# Skipping row 1974 due to NaN audience: IC02, 야구, 2024-08-07
# Skipping row 1975 due to NaN audience: CW01, 야구, 2024-08-07
# Skipping row 1978 due to NaN audience: BS02, 야구, 2024-08-08
# Skipping row 1979 due to NaN audience: SU03, 야구, 2024-08-08
# Skipping row 1980 due to NaN audience: CW01, 야구, 2024-08-08
# Skipping row 1982 due to NaN audience: SO04, 야구, 2024-08-09
# Skipping row 1983 due to NaN audience: BS02, 야구, 2024-08-09
# Skipping row 1985 due to NaN audience: CW01, 야구, 2024-08-09
# Skipping row 1986 due to NaN audience: SO04, 야구, 2024-08-10
# Skipping row 1988 due to NaN audience: BS02, 야구, 2024-08-10
# Skipping row 1990 due to NaN audience: CW01, 야구, 2024-08-10
# Skipping row 1991 due to NaN audience: DG03, 야구, 2024-08-12
# Skipping row 1992 due to NaN audience: SU03, 야구, 2024-08-12
# Skipping row 1993 due to NaN audience: DJ02, 야구, 2024-08-12
# Skipping row 1994 due to NaN audience: SO05, 야구, 2024-08-12
# Skipping row 1995 due to NaN audience: IC02, 야구, 2024-08-12
# Skipping row 1997 due to NaN audience: SU03, 야구, 2024-08-13
# Skipping row 1999 due to NaN audience: SO05, 야구, 2024-08-13
# Skipping row 2000 due to NaN audience: IC02, 야구, 2024-08-13
# Skipping row 2002 due to NaN audience: SU03, 야구, 2024-08-14
# Skipping row 2005 due to NaN audience: IC02, 야구, 2024-08-14
# Skipping row 2009 due to NaN audience: IC02, 야구, 2024-08-15
# Skipping row 2010 due to NaN audience: BS02, 야구, 2024-08-15
# Skipping row 2013 due to NaN audience: SO04, 야구, 2024-08-16
# Skipping row 2016 due to NaN audience: SO04, 야구, 2024-08-17
# Skipping row 2021 due to NaN audience: SO05, 야구, 2024-08-19
# Skipping row 2022 due to NaN audience: DJ02, 야구, 2024-08-19
# Skipping row 2023 due to NaN audience: SU03, 야구, 2024-08-19
# Skipping row 2024 due to NaN audience: GJ02, 야구, 2024-08-19
# Skipping row 2025 due to NaN audience: CW01, 야구, 2024-08-19
# Skipping row 2027 due to NaN audience: DJ02, 야구, 2024-08-20
# Skipping row 2029 due to NaN audience: GJ02, 야구, 2024-08-20
# Skipping row 2030 due to NaN audience: CW01, 야구, 2024-08-20
# Skipping row 2032 due to NaN audience: DJ02, 야구, 2024-08-21
# Skipping row 2035 due to NaN audience: CW01, 야구, 2024-08-21
# Skipping row 2038 due to NaN audience: CW01, 야구, 2024-08-22
# Skipping row 2039 due to NaN audience: DJ02, 야구, 2024-08-22
# Skipping row 2040 due to NaN audience: DG03, 야구, 2024-08-22
# Skipping row 2042 due to NaN audience: GJ02, 야구, 2024-08-23
# Skipping row 2044 due to NaN audience: DJ02, 야구, 2024-08-23
# Skipping row 2047 due to NaN audience: GJ02, 야구, 2024-08-24
# Skipping row 2049 due to NaN audience: DJ02, 야구, 2024-08-24
# Skipping row 2051 due to NaN audience: SO04, 야구, 2024-08-26
# Skipping row 2052 due to NaN audience: IC02, 야구, 2024-08-26
# Skipping row 2053 due to NaN audience: BS02, 야구, 2024-08-26
# Skipping row 2054 due to NaN audience: CW01, 야구, 2024-08-26
# Skipping row 2055 due to NaN audience: SO05, 야구, 2024-08-26
# Skipping row 2057 due to NaN audience: IC02, 야구, 2024-08-27
# Skipping row 2062 due to NaN audience: IC02, 야구, 2024-08-28
# Skipping row 2066 due to NaN audience: SU03, 야구, 2024-08-29
# Skipping row 2067 due to NaN audience: IC02, 야구, 2024-08-29
# Skipping row 2069 due to NaN audience: DJ02, 야구, 2024-08-29
# Skipping row 2072 due to NaN audience: IC02, 야구, 2024-08-30
# Skipping row 2073 due to NaN audience: BS02, 야구, 2024-08-30
# Skipping row 2074 due to NaN audience: DJ02, 야구, 2024-08-30
# Skipping row 2075 due to NaN audience: SO05, 야구, 2024-08-30
# Skipping row 2076 due to NaN audience: SU03, 야구, 2024-08-31
# Skipping row 2078 due to NaN audience: BS02, 야구, 2024-08-31
# Skipping row 2309 due to NaN audience: BS01, 축구, 2023-12-06
# Skipping row 2310 due to NaN audience: GP01, 축구, 2023-12-06
# Skipping row 2311 due to NaN audience: SU02, 축구, 2023-12-09
# Skipping row 2312 due to NaN audience: GN01, 축구, 2023-12-09
# Skipping row 2541 due to NaN audience: CA01, 축구, 2024-11-28
# Skipping row 2542 due to NaN audience: DG01, 축구, 2024-12-01
# Skipping row 2543 due to NaN audience: SO03, 축구, 2024-12-01
# Skipping row 2544 due to NaN audience: JJ01, 축구, 2024-12-08
# Skipping row 2545 due to NaN audience: GY01, 농구, 2023-01-01
# Skipping row 2546 due to NaN audience: SO06, 농구, 2023-01-01
# Skipping row 2547 due to NaN audience: CW02, 농구, 2023-01-01
# Skipping row 2548 due to NaN audience: WJ01, 농구, 2023-01-02
# Skipping row 2549 due to NaN audience: GS01, 농구, 2023-01-03
# Skipping row 2550 due to NaN audience: SO07, 농구, 2023-01-04
# Skipping row 2551 due to NaN audience: GY01, 농구, 2023-01-05
# Skipping row 2552 due to NaN audience: SO06, 농구, 2023-01-05
# Skipping row 2553 due to NaN audience: GS01, 농구, 2023-01-06
# Skipping row 2554 due to NaN audience: AY01, 농구, 2023-01-06
# Skipping row 2555 due to NaN audience: US04, 농구, 2023-01-07
# Skipping row 2556 due to NaN audience: CW02, 농구, 2023-01-07
# Skipping row 2557 due to NaN audience: DG04, 농구, 2023-01-07
# Skipping row 2558 due to NaN audience: US04, 농구, 2023-01-08
# Skipping row 2559 due to NaN audience: AY01, 농구, 2023-01-08
# Skipping row 2560 due to NaN audience: SO06, 농구, 2023-01-08
# Skipping row 2561 due to NaN audience: GY01, 농구, 2023-01-09
# Skipping row 2562 due to NaN audience: SU04, 농구, 2023-01-10
# Skipping row 2563 due to NaN audience: SO07, 농구, 2023-01-10
# Skipping row 2564 due to NaN audience: US04, 농구, 2023-01-11
# Skipping row 2565 due to NaN audience: SU04, 농구, 2023-01-15
# Skipping row 2566 due to NaN audience: WJ01, 농구, 2023-01-17
# Skipping row 2567 due to NaN audience: GY01, 농구, 2023-01-19
# Skipping row 2568 due to NaN audience: SO06, 농구, 2023-01-19
# Skipping row 2569 due to NaN audience: CW02, 농구, 2023-01-20
# Skipping row 2570 due to NaN audience: US04, 농구, 2023-01-20
# Skipping row 2571 due to NaN audience: SU04, 농구, 2023-01-21
# Skipping row 2572 due to NaN audience: GY01, 농구, 2023-01-21
# Skipping row 2573 due to NaN audience: SO06, 농구, 2023-01-21
# Skipping row 2574 due to NaN audience: DG04, 농구, 2023-01-22
# Skipping row 2575 due to NaN audience: CW02, 농구, 2023-01-22
# Skipping row 2576 due to NaN audience: AY01, 농구, 2023-01-22
# Skipping row 2577 due to NaN audience: WJ01, 농구, 2023-01-23
# Skipping row 2578 due to NaN audience: SO07, 농구, 2023-01-23
# Skipping row 2579 due to NaN audience: US04, 농구, 2023-01-24
# Skipping row 2580 due to NaN audience: JJ02, 농구, 2023-01-24
# Skipping row 2581 due to NaN audience: WJ01, 농구, 2023-01-26
# Skipping row 2582 due to NaN audience: SO06, 농구, 2023-01-27
# Skipping row 2583 due to NaN audience: SU04, 농구, 2023-01-27
# Skipping row 2584 due to NaN audience: SO07, 농구, 2023-01-28
# Skipping row 2585 due to NaN audience: CW02, 농구, 2023-01-28
# Skipping row 2586 due to NaN audience: WJ01, 농구, 2023-01-28
# Skipping row 2587 due to NaN audience: SU04, 농구, 2023-01-29
# Skipping row 2588 due to NaN audience: AY01, 농구, 2023-01-29
# Skipping row 2589 due to NaN audience: US04, 농구, 2023-01-29
# Skipping row 2590 due to NaN audience: GY01, 농구, 2023-01-30
# Skipping row 2591 due to NaN audience: SU04, 농구, 2023-01-31
# Skipping row 2592 due to NaN audience: JJ02, 농구, 2023-01-31
# Skipping row 2593 due to NaN audience: SO07, 농구, 2023-02-01
# Skipping row 2594 due to NaN audience: GY01, 농구, 2023-02-02
# Skipping row 2595 due to NaN audience: SO06, 농구, 2023-02-02
# Skipping row 2596 due to NaN audience: CW02, 농구, 2023-02-03
# Skipping row 2597 due to NaN audience: AY01, 농구, 2023-02-04
# Skipping row 2598 due to NaN audience: US04, 농구, 2023-02-04
# Skipping row 2599 due to NaN audience: DG04, 농구, 2023-02-04
# Skipping row 2600 due to NaN audience: US04, 농구, 2023-02-05
# Skipping row 2601 due to NaN audience: JJ02, 농구, 2023-02-05
# Skipping row 2602 due to NaN audience: SO07, 농구, 2023-02-05
# Skipping row 2603 due to NaN audience: SU04, 농구, 2023-02-06
# Skipping row 2604 due to NaN audience: SO07, 농구, 2023-02-07
# Skipping row 2605 due to NaN audience: DG04, 농구, 2023-02-08
# Skipping row 2606 due to NaN audience: AY01, 농구, 2023-02-09
# Skipping row 2607 due to NaN audience: JJ02, 농구, 2023-02-09
# Skipping row 2608 due to NaN audience: CW02, 농구, 2023-02-10
# Skipping row 2609 due to NaN audience: GY01, 농구, 2023-02-10
# Skipping row 2610 due to NaN audience: SO07, 농구, 2023-02-11
# Skipping row 2611 due to NaN audience: AY01, 농구, 2023-02-11
# Skipping row 2612 due to NaN audience: SO07, 농구, 2023-02-12
# Skipping row 2613 due to NaN audience: SU04, 농구, 2023-02-12
# Skipping row 2614 due to NaN audience: DG04, 농구, 2023-02-12
# Skipping row 2615 due to NaN audience: SO06, 농구, 2023-02-13
# Skipping row 2616 due to NaN audience: SO07, 농구, 2023-02-14
# Skipping row 2617 due to NaN audience: AY01, 농구, 2023-02-15
# Skipping row 2618 due to NaN audience: DG04, 농구, 2023-02-16
# Skipping row 2619 due to NaN audience: SO06, 농구, 2023-02-16
# Skipping row 2620 due to NaN audience: CW02, 농구, 2023-02-17
# Skipping row 2621 due to NaN audience: AY01, 농구, 2023-02-17
# Skipping row 2622 due to NaN audience: WJ01, 농구, 2023-02-18
# Skipping row 2623 due to NaN audience: SO06, 농구, 2023-02-18
# Skipping row 2624 due to NaN audience: US04, 농구, 2023-02-18
# Skipping row 2625 due to NaN audience: GY01, 농구, 2023-02-19
# Skipping row 2626 due to NaN audience: DG04, 농구, 2023-02-19
# Skipping row 2627 due to NaN audience: SO07, 농구, 2023-02-19
# Skipping row 2628 due to NaN audience: JJ02, 농구, 2023-02-23
# Skipping row 2629 due to NaN audience: WJ01, 농구, 2023-02-25
# Skipping row 2630 due to NaN audience: AY01, 농구, 2023-02-26
# Skipping row 2631 due to NaN audience: JJ02, 농구, 2023-03-01
# Skipping row 2632 due to NaN audience: DG04, 농구, 2023-03-01
# Skipping row 2633 due to NaN audience: SU04, 농구, 2023-03-01
# Skipping row 2634 due to NaN audience: US04, 농구, 2023-03-02
# Skipping row 2635 due to NaN audience: WJ01, 농구, 2023-03-04
# Skipping row 2636 due to NaN audience: GY01, 농구, 2023-03-04
# Skipping row 2637 due to NaN audience: SO06, 농구, 2023-03-04
# Skipping row 2638 due to NaN audience: CW02, 농구, 2023-03-04
# Skipping row 2639 due to NaN audience: WJ01, 농구, 2023-03-07
# Skipping row 2640 due to NaN audience: SO07, 농구, 2023-03-08
# Skipping row 2641 due to NaN audience: JJ02, 농구, 2023-03-09
# Skipping row 2642 due to NaN audience: DG04, 농구, 2023-03-09
# Skipping row 2643 due to NaN audience: US04, 농구, 2023-03-10
# Skipping row 2644 due to NaN audience: SO06, 농구, 2023-03-10
# Skipping row 2645 due to NaN audience: GY01, 농구, 2023-03-11
# Skipping row 2646 due to NaN audience: JJ02, 농구, 2023-03-11
# Skipping row 2647 due to NaN audience: DG04, 농구, 2023-03-11
# Skipping row 2648 due to NaN audience: JJ02, 농구, 2023-03-12
# Skipping row 2649 due to NaN audience: SO07, 농구, 2023-03-12
# Skipping row 2650 due to NaN audience: WJ01, 농구, 2023-03-12
# Skipping row 2651 due to NaN audience: SU04, 농구, 2023-03-13
# Skipping row 2652 due to NaN audience: US04, 농구, 2023-03-14
# Skipping row 2653 due to NaN audience: GY01, 농구, 2023-03-15
# Skipping row 2654 due to NaN audience: SO06, 농구, 2023-03-16
# Skipping row 2655 due to NaN audience: AY01, 농구, 2023-03-16
# Skipping row 2656 due to NaN audience: DG04, 농구, 2023-03-17
# Skipping row 2657 due to NaN audience: US04, 농구, 2023-03-17
# Skipping row 2658 due to NaN audience: SO06, 농구, 2023-03-18
# Skipping row 2659 due to NaN audience: WJ01, 농구, 2023-03-18
# Skipping row 2660 due to NaN audience: AY01, 농구, 2023-03-18
# Skipping row 2661 due to NaN audience: SO06, 농구, 2023-03-19
# Skipping row 2662 due to NaN audience: SU04, 농구, 2023-03-19
# Skipping row 2663 due to NaN audience: CW02, 농구, 2023-03-19
# Skipping row 2664 due to NaN audience: AY01, 농구, 2023-03-20
# Skipping row 2665 due to NaN audience: US04, 농구, 2023-03-21
# Skipping row 2666 due to NaN audience: SO07, 농구, 2023-03-22
# Skipping row 2667 due to NaN audience: CW02, 농구, 2023-03-23
# Skipping row 2668 due to NaN audience: WJ01, 농구, 2023-03-23
# Skipping row 2669 due to NaN audience: SO07, 농구, 2023-03-24
# Skipping row 2670 due to NaN audience: US04, 농구, 2023-03-24
# Skipping row 2671 due to NaN audience: SU04, 농구, 2023-03-25
# Skipping row 2672 due to NaN audience: SO06, 농구, 2023-03-25
# Skipping row 2673 due to NaN audience: WJ01, 농구, 2023-03-25
# Skipping row 2674 due to NaN audience: JJ02, 농구, 2023-03-26
# Skipping row 2675 due to NaN audience: CW02, 농구, 2023-03-26
# Skipping row 2676 due to NaN audience: AY01, 농구, 2023-03-26
# Skipping row 2677 due to NaN audience: GY01, 농구, 2023-03-27
# Skipping row 2678 due to NaN audience: SO06, 농구, 2023-03-27
# Skipping row 2679 due to NaN audience: SO07, 농구, 2023-03-29
# Skipping row 2680 due to NaN audience: CW02, 농구, 2023-03-29
# Skipping row 2681 due to NaN audience: SU04, 농구, 2023-03-29
# Skipping row 2682 due to NaN audience: JJ02, 농구, 2023-03-29
# Skipping row 2683 due to NaN audience: GY01, 농구, 2023-03-29
# Skipping row 2684 due to NaN audience: US04, 농구, 2023-04-02
# Skipping row 2685 due to NaN audience: SO07, 농구, 2023-04-03
# Skipping row 2686 due to NaN audience: US04, 농구, 2023-04-04
# Skipping row 2687 due to NaN audience: SO07, 농구, 2023-04-05
# Skipping row 2688 due to NaN audience: GY01, 농구, 2023-04-06
# Skipping row 2689 due to NaN audience: JJ02, 농구, 2023-04-07
# Skipping row 2690 due to NaN audience: GY01, 농구, 2023-04-08
# Skipping row 2691 due to NaN audience: US04, 농구, 2023-04-10
# Skipping row 2692 due to NaN audience: AY01, 농구, 2023-04-13
# Skipping row 2693 due to NaN audience: CW02, 농구, 2023-04-14
# Skipping row 2694 due to NaN audience: AY01, 농구, 2023-04-15
# Skipping row 2695 due to NaN audience: CW02, 농구, 2023-04-16
# Skipping row 2696 due to NaN audience: GY01, 농구, 2023-04-17
# Skipping row 2697 due to NaN audience: SO07, 농구, 2023-04-18
# Skipping row 2698 due to NaN audience: GY01, 농구, 2023-04-19
# Skipping row 2699 due to NaN audience: AY01, 농구, 2023-04-25
# Skipping row 2700 due to NaN audience: AY01, 농구, 2023-04-27
# Skipping row 2701 due to NaN audience: SO07, 농구, 2023-04-29
# Skipping row 2702 due to NaN audience: SO07, 농구, 2023-05-01
# Skipping row 2703 due to NaN audience: SO07, 농구, 2023-05-03
# Skipping row 2704 due to NaN audience: AY01, 농구, 2023-05-05
# Skipping row 2705 due to NaN audience: AY01, 농구, 2023-05-07
# Skipping row 2706 due to NaN audience: AY01, 농구, 2023-10-21
# Skipping row 2707 due to NaN audience: CW02, 농구, 2023-10-21
# Skipping row 2708 due to NaN audience: US04, 농구, 2023-10-21
# Skipping row 2709 due to NaN audience: SO07, 농구, 2023-10-22
# Skipping row 2710 due to NaN audience: GY01, 농구, 2023-10-22
# Skipping row 2711 due to NaN audience: BS03, 농구, 2023-10-22
# Skipping row 2712 due to NaN audience: US04, 농구, 2023-10-23
# Skipping row 2713 due to NaN audience: GY01, 농구, 2023-10-24
# Skipping row 2714 due to NaN audience: CW02, 농구, 2023-10-26
# Skipping row 2715 due to NaN audience: US04, 농구, 2023-10-27
# Skipping row 2716 due to NaN audience: SO06, 농구, 2023-10-27
# Skipping row 2717 due to NaN audience: WJ01, 농구, 2023-10-28
# Skipping row 2718 due to NaN audience: DG04, 농구, 2023-10-28
# Skipping row 2719 due to NaN audience: SU04, 농구, 2023-10-28
# Skipping row 2720 due to NaN audience: SO06, 농구, 2023-10-29
# Skipping row 2721 due to NaN audience: DG04, 농구, 2023-10-29
# Skipping row 2722 due to NaN audience: GY01, 농구, 2023-10-29
# Skipping row 2723 due to NaN audience: SU04, 농구, 2023-10-30
# Skipping row 2724 due to NaN audience: AY01, 농구, 2023-10-31
# Skipping row 2725 due to NaN audience: SO06, 농구, 2023-10-31
# Skipping row 2726 due to NaN audience: CW02, 농구, 2023-11-02
# Skipping row 2727 due to NaN audience: SO06, 농구, 2023-11-02
# Skipping row 2728 due to NaN audience: US04, 농구, 2023-11-03
# Skipping row 2729 due to NaN audience: DG04, 농구, 2023-11-03
# Skipping row 2730 due to NaN audience: CW02, 농구, 2023-11-04
# Skipping row 2731 due to NaN audience: AY01, 농구, 2023-11-04
# Skipping row 2732 due to NaN audience: SO06, 농구, 2023-11-04
# Skipping row 2733 due to NaN audience: US04, 농구, 2023-11-05
# Skipping row 2734 due to NaN audience: DG04, 농구, 2023-11-05
# Skipping row 2735 due to NaN audience: SU04, 농구, 2023-11-06
# Skipping row 2736 due to NaN audience: AY01, 농구, 2023-11-07
# Skipping row 2737 due to NaN audience: WJ01, 농구, 2023-11-07
# Skipping row 2738 due to NaN audience: SU04, 농구, 2023-11-09
# Skipping row 2739 due to NaN audience: US04, 농구, 2023-11-09
# Skipping row 2740 due to NaN audience: CW02, 농구, 2023-11-10
# Skipping row 2741 due to NaN audience: WJ01, 농구, 2023-11-10
# Skipping row 2742 due to NaN audience: SO06, 농구, 2023-11-11
# Skipping row 2743 due to NaN audience: DG04, 농구, 2023-11-11
# Skipping row 2744 due to NaN audience: SU04, 농구, 2023-11-11
# Skipping row 2745 due to NaN audience: WJ01, 농구, 2023-11-12
# Skipping row 2746 due to NaN audience: AY01, 농구, 2023-11-12
# Skipping row 2747 due to NaN audience: GY01, 농구, 2023-11-12
# Skipping row 2748 due to NaN audience: US04, 농구, 2023-11-13
# Skipping row 2749 due to NaN audience: WJ01, 농구, 2023-11-14
# Skipping row 2750 due to NaN audience: SO06, 농구, 2023-11-14
# Skipping row 2751 due to NaN audience: WJ01, 농구, 2023-11-16
# Skipping row 2752 due to NaN audience: DG04, 농구, 2023-11-16
# Skipping row 2753 due to NaN audience: BS03, 농구, 2023-11-17
# Skipping row 2754 due to NaN audience: AY01, 농구, 2023-11-17
# Skipping row 2755 due to NaN audience: SU04, 농구, 2023-11-18
# Skipping row 2756 due to NaN audience: US04, 농구, 2023-11-18
# Skipping row 2757 due to NaN audience: WJ01, 농구, 2023-11-18
# Skipping row 2758 due to NaN audience: CW02, 농구, 2023-11-19
# Skipping row 2759 due to NaN audience: AY01, 농구, 2023-11-19
# Skipping row 2760 due to NaN audience: GY01, 농구, 2023-11-19
# Skipping row 2761 due to NaN audience: SO07, 농구, 2023-11-20
# Skipping row 2762 due to NaN audience: SU04, 농구, 2023-11-21
# Skipping row 2763 due to NaN audience: DG04, 농구, 2023-11-21
# Skipping row 2764 due to NaN audience: CW02, 농구, 2023-11-23
# Skipping row 2765 due to NaN audience: SO06, 농구, 2023-11-23
# Skipping row 2766 due to NaN audience: AY01, 농구, 2023-11-24
# Skipping row 2767 due to NaN audience: SO07, 농구, 2023-11-24
# Skipping row 2768 due to NaN audience: CW02, 농구, 2023-11-25
# Skipping row 2769 due to NaN audience: SO06, 농구, 2023-11-25
# Skipping row 2770 due to NaN audience: BS03, 농구, 2023-11-25
# Skipping row 2771 due to NaN audience: SU04, 농구, 2023-11-26
# Skipping row 2772 due to NaN audience: AY01, 농구, 2023-11-26
# Skipping row 2773 due to NaN audience: GY01, 농구, 2023-11-26
# Skipping row 2774 due to NaN audience: BS03, 농구, 2023-11-27
# Skipping row 2775 due to NaN audience: SU04, 농구, 2023-11-28
# Skipping row 2776 due to NaN audience: GY01, 농구, 2023-11-28
# Skipping row 2777 due to NaN audience: BS03, 농구, 2023-11-30
# Skipping row 2778 due to NaN audience: SO07, 농구, 2023-11-30
# Skipping row 2779 due to NaN audience: AY01, 농구, 2023-12-01
# Skipping row 2780 due to NaN audience: SO06, 농구, 2023-12-01
# Skipping row 2781 due to NaN audience: WJ01, 농구, 2023-12-02
# Skipping row 2782 due to NaN audience: SO07, 농구, 2023-12-02
# Skipping row 2783 due to NaN audience: DG04, 농구, 2023-12-02
# Skipping row 2784 due to NaN audience: US04, 농구, 2023-12-03
# Skipping row 2785 due to NaN audience: SO07, 농구, 2023-12-03
# Skipping row 2786 due to NaN audience: BS03, 농구, 2023-12-03
# Skipping row 2787 due to NaN audience: WJ01, 농구, 2023-12-04
# Skipping row 2788 due to NaN audience: SO06, 농구, 2023-12-05
# Skipping row 2789 due to NaN audience: SU04, 농구, 2023-12-05
# Skipping row 2790 due to NaN audience: CW02, 농구, 2023-12-07
# Skipping row 2791 due to NaN audience: US04, 농구, 2023-12-07
# Skipping row 2792 due to NaN audience: GY01, 농구, 2023-12-08
# Skipping row 2793 due to NaN audience: WJ01, 농구, 2023-12-08
# Skipping row 2794 due to NaN audience: US04, 농구, 2023-12-09
# Skipping row 2795 due to NaN audience: CW02, 농구, 2023-12-09
# Skipping row 2796 due to NaN audience: GY01, 농구, 2023-12-10
# Skipping row 2797 due to NaN audience: WJ01, 농구, 2023-12-10
# Skipping row 2798 due to NaN audience: US04, 농구, 2023-12-11
# Skipping row 2799 due to NaN audience: SU04, 농구, 2023-12-12
# Skipping row 2800 due to NaN audience: WJ01, 농구, 2023-12-12
# Skipping row 2801 due to NaN audience: BS03, 농구, 2023-12-12
# Skipping row 2802 due to NaN audience: DG04, 농구, 2023-12-14
# Skipping row 2803 due to NaN audience: SU04, 농구, 2023-12-15
# Skipping row 2804 due to NaN audience: BS03, 농구, 2023-12-15
# Skipping row 2805 due to NaN audience: AY01, 농구, 2023-12-16
# Skipping row 2806 due to NaN audience: DG04, 농구, 2023-12-16
# Skipping row 2807 due to NaN audience: SO07, 농구, 2023-12-16
# Skipping row 2808 due to NaN audience: WJ01, 농구, 2023-12-17
# Skipping row 2809 due to NaN audience: CW02, 농구, 2023-12-17
# Skipping row 2810 due to NaN audience: BS03, 농구, 2023-12-17
# Skipping row 2811 due to NaN audience: AY01, 농구, 2023-12-18
# Skipping row 2812 due to NaN audience: SU04, 농구, 2023-12-19
# Skipping row 2813 due to NaN audience: US04, 농구, 2023-12-19
# Skipping row 2814 due to NaN audience: DG04, 농구, 2023-12-21
# Skipping row 2815 due to NaN audience: GY01, 농구, 2023-12-21
# Skipping row 2816 due to NaN audience: US04, 농구, 2023-12-22
# Skipping row 2817 due to NaN audience: AY01, 농구, 2023-12-22
# Skipping row 2818 due to NaN audience: CW02, 농구, 2023-12-23
# Skipping row 2819 due to NaN audience: GY01, 농구, 2023-12-23
# Skipping row 2820 due to NaN audience: DG04, 농구, 2023-12-23
# Skipping row 2821 due to NaN audience: GY01, 농구, 2023-12-24
# Skipping row 2822 due to NaN audience: AY01, 농구, 2023-12-24
# Skipping row 2823 due to NaN audience: CW02, 농구, 2023-12-24
# Skipping row 2824 due to NaN audience: WJ01, 농구, 2023-12-25
# Skipping row 2825 due to NaN audience: SO07, 농구, 2023-12-25
# Skipping row 2826 due to NaN audience: DG04, 농구, 2023-12-25
# Skipping row 2827 due to NaN audience: CW02, 농구, 2023-12-26
# Skipping row 2828 due to NaN audience: DG04, 농구, 2023-12-28
# Skipping row 2829 due to NaN audience: GY01, 농구, 2023-12-28
# Skipping row 2830 due to NaN audience: US04, 농구, 2023-12-28
# Skipping row 2831 due to NaN audience: WJ01, 농구, 2023-12-29
# Skipping row 2832 due to NaN audience: GY01, 농구, 2023-12-30
# Skipping row 2833 due to NaN audience: AY01, 농구, 2023-12-30
# Skipping row 2834 due to NaN audience: SU04, 농구, 2023-12-30
# Skipping row 2835 due to NaN audience: AY01, 농구, 2023-12-31
# Skipping row 2836 due to NaN audience: CW02, 농구, 2023-12-31
# Skipping row 2837 due to NaN audience: DG04, 농구, 2023-12-31
# Skipping row 2838 due to NaN audience: SU04, 농구, 2024-01-01
# Skipping row 2839 due to NaN audience: SO06, 농구, 2024-01-01
# Skipping row 2840 due to NaN audience: WJ01, 농구, 2024-01-02
# Skipping row 2841 due to NaN audience: AY01, 농구, 2024-01-02
# Skipping row 2842 due to NaN audience: BS03, 농구, 2024-01-03
# Skipping row 2843 due to NaN audience: DG04, 농구, 2024-01-04
# Skipping row 2844 due to NaN audience: SO06, 농구, 2024-01-04
# Skipping row 2845 due to NaN audience: SO07, 농구, 2024-01-05
# Skipping row 2846 due to NaN audience: CW02, 농구, 2024-01-06
# Skipping row 2847 due to NaN audience: US04, 농구, 2024-01-06
# Skipping row 2848 due to NaN audience: SO06, 농구, 2024-01-06
# Skipping row 2849 due to NaN audience: SO07, 농구, 2024-01-07
# Skipping row 2850 due to NaN audience: BS03, 농구, 2024-01-07
# Skipping row 2851 due to NaN audience: CW02, 농구, 2024-01-07
# Skipping row 2852 due to NaN audience: WJ01, 농구, 2024-01-08
# Skipping row 2853 due to NaN audience: DG04, 농구, 2024-01-08
# Skipping row 2854 due to NaN audience: CW02, 농구, 2024-01-09
# Skipping row 2855 due to NaN audience: BS03, 농구, 2024-01-09
# Skipping row 2856 due to NaN audience: BS03, 농구, 2024-01-11
# Skipping row 2857 due to NaN audience: GY01, 농구, 2024-01-14
# Skipping row 2858 due to NaN audience: BS03, 농구, 2024-01-17
# Skipping row 2859 due to NaN audience: GY01, 농구, 2024-01-17
# Skipping row 2860 due to NaN audience: DG04, 농구, 2024-01-18
# Skipping row 2861 due to NaN audience: SO07, 농구, 2024-01-18
# Skipping row 2862 due to NaN audience: BS03, 농구, 2024-01-19
# Skipping row 2863 due to NaN audience: AY01, 농구, 2024-01-19
# Skipping row 2864 due to NaN audience: US04, 농구, 2024-01-20
# Skipping row 2865 due to NaN audience: SO07, 농구, 2024-01-20
# Skipping row 2866 due to NaN audience: GY01, 농구, 2024-01-20
# Skipping row 2867 due to NaN audience: WJ01, 농구, 2024-01-21
# Skipping row 2868 due to NaN audience: SO06, 농구, 2024-01-21
# Skipping row 2869 due to NaN audience: AY01, 농구, 2024-01-21
# ...
# Skipping row 2879 due to NaN audience: SO07, 농구, 2024-01-27
# Skipping row 2880 due to NaN audience: SU04, 농구, 2024-01-28
# Skipping row 2881 due to NaN audience: US04, 농구, 2024-01-28
# Skipping row 2882 due to NaN audience: GY01, 농구, 2024-01-28
# Skipping row 2883 due to NaN audience: BS03, 농구, 2024-01-29
# Skipping row 2884 due to NaN audience: GY01, 농구, 2024-01-30
# Skipping row 2885 due to NaN audience: SO06, 농구, 2024-01-30
# Skipping row 2886 due to NaN audience: SU04, 농구, 2024-02-01
# Skipping row 2887 due to NaN audience: GY01, 농구, 2024-02-01
# Skipping row 2888 due to NaN audience: US04, 농구, 2024-02-02
# Skipping row 2889 due to NaN audience: BS03, 농구, 2024-02-02
# Skipping row 2890 due to NaN audience: SO07, 농구, 2024-02-03
# Skipping row 2891 due to NaN audience: DG04, 농구, 2024-02-03
# Skipping row 2892 due to NaN audience: SO06, 농구, 2024-02-03
# Skipping row 2893 due to NaN audience: AY01, 농구, 2024-02-04
# Skipping row 2894 due to NaN audience: US04, 농구, 2024-02-04
# Skipping row 2895 due to NaN audience: SO06, 농구, 2024-02-04
# Skipping row 2896 due to NaN audience: GY01, 농구, 2024-02-05
# Skipping row 2897 due to NaN audience: CW02, 농구, 2024-02-06
# Skipping row 2898 due to NaN audience: DG04, 농구, 2024-02-06
# Skipping row 2899 due to NaN audience: BS03, 농구, 2024-02-08
# Skipping row 2900 due to NaN audience: DG04, 농구, 2024-02-08
# Skipping row 2901 due to NaN audience: SU04, 농구, 2024-02-09
# Skipping row 2902 due to NaN audience: GY01, 농구, 2024-02-09
# Skipping row 2903 due to NaN audience: SO07, 농구, 2024-02-10
# Skipping row 2904 due to NaN audience: DG04, 농구, 2024-02-10
# Skipping row 2905 due to NaN audience: US04, 농구, 2024-02-10
# Skipping row 2906 due to NaN audience: SO06, 농구, 2024-02-11
# Skipping row 2907 due to NaN audience: AY01, 농구, 2024-02-11
# Skipping row 2908 due to NaN audience: WJ01, 농구, 2024-02-11
# Skipping row 2909 due to NaN audience: CW02, 농구, 2024-02-12
# Skipping row 2910 due to NaN audience: BS03, 농구, 2024-02-12
# Skipping row 2911 due to NaN audience: WJ01, 농구, 2024-02-13
# Skipping row 2912 due to NaN audience: SO06, 농구, 2024-02-13
# Skipping row 2913 due to NaN audience: SU04, 농구, 2024-02-14
# Skipping row 2914 due to NaN audience: GY01, 농구, 2024-02-14
# Skipping row 2915 due to NaN audience: AY01, 농구, 2024-02-15
# Skipping row 2916 due to NaN audience: SO07, 농구, 2024-02-15
# Skipping row 2917 due to NaN audience: US04, 농구, 2024-02-28
# Skipping row 2918 due to NaN audience: SO07, 농구, 2024-02-28
# Skipping row 2919 due to NaN audience: BS03, 농구, 2024-02-29
# Skipping row 2920 due to NaN audience: SO06, 농구, 2024-02-29
# Skipping row 2921 due to NaN audience: SO07, 농구, 2024-03-01
# Skipping row 2922 due to NaN audience: US04, 농구, 2024-03-01
# Skipping row 2923 due to NaN audience: CW02, 농구, 2024-03-01
# Skipping row 2924 due to NaN audience: BS03, 농구, 2024-03-02
# Skipping row 2925 due to NaN audience: WJ01, 농구, 2024-03-02
# Skipping row 2926 due to NaN audience: SO06, 농구, 2024-03-02
# Skipping row 2927 due to NaN audience: SU04, 농구, 2024-03-03
# Skipping row 2928 due to NaN audience: AY01, 농구, 2024-03-03
# Skipping row 2929 due to NaN audience: SO07, 농구, 2024-03-03
# Skipping row 2930 due to NaN audience: SO06, 농구, 2024-03-04
# Skipping row 2931 due to NaN audience: GY01, 농구, 2024-03-05
# Skipping row 2932 due to NaN audience: SO07, 농구, 2024-03-05
# Skipping row 2933 due to NaN audience: CW02, 농구, 2024-03-07
# Skipping row 2934 due to NaN audience: SO06, 농구, 2024-03-07
# Skipping row 2935 due to NaN audience: SU04, 농구, 2024-03-07
# Skipping row 2936 due to NaN audience: SU04, 농구, 2024-03-09
# Skipping row 2937 due to NaN audience: WJ01, 농구, 2024-03-09
# Skipping row 2938 due to NaN audience: SO06, 농구, 2024-03-09
# Skipping row 2939 due to NaN audience: CW02, 농구, 2024-03-11
# Skipping row 2940 due to NaN audience: AY01, 농구, 2024-03-13
# Skipping row 2941 due to NaN audience: SO07, 농구, 2024-03-13
# Skipping row 2942 due to NaN audience: WJ01, 농구, 2024-03-14
# Skipping row 2943 due to NaN audience: AY01, 농구, 2024-03-14
# Skipping row 2944 due to NaN audience: DG04, 농구, 2024-03-15
# Skipping row 2945 due to NaN audience: GY01, 농구, 2024-03-15
# Skipping row 2946 due to NaN audience: SU04, 농구, 2024-03-16
# Skipping row 2947 due to NaN audience: US04, 농구, 2024-03-16
# Skipping row 2948 due to NaN audience: AY01, 농구, 2024-03-16
# Skipping row 2949 due to NaN audience: DG04, 농구, 2024-03-17
# Skipping row 2950 due to NaN audience: BS03, 농구, 2024-03-17
# Skipping row 2951 due to NaN audience: CW02, 농구, 2024-03-17
# Skipping row 2952 due to NaN audience: SO06, 농구, 2024-03-18
# Skipping row 2953 due to NaN audience: CW02, 농구, 2024-03-19
# Skipping row 2954 due to NaN audience: SO07, 농구, 2024-03-19
# Skipping row 2955 due to NaN audience: BS03, 농구, 2024-03-20
# Skipping row 2956 due to NaN audience: AY01, 농구, 2024-03-21
# Skipping row 2957 due to NaN audience: SO07, 농구, 2024-03-21
# Skipping row 2958 due to NaN audience: BS03, 농구, 2024-03-22
# Skipping row 2959 due to NaN audience: GY01, 농구, 2024-03-22
# Skipping row 2960 due to NaN audience: SU04, 농구, 2024-03-23
# Skipping row 2961 due to NaN audience: WJ01, 농구, 2024-03-23
# Skipping row 2962 due to NaN audience: SO07, 농구, 2024-03-23
# Skipping row 2963 due to NaN audience: US04, 농구, 2024-03-24
# Skipping row 2964 due to NaN audience: WJ01, 농구, 2024-03-24
# Skipping row 2965 due to NaN audience: SO06, 농구, 2024-03-24
# Skipping row 2966 due to NaN audience: SO07, 농구, 2024-03-25
# Skipping row 2967 due to NaN audience: BS03, 농구, 2024-03-26
# Skipping row 2968 due to NaN audience: DG04, 농구, 2024-03-26
# Skipping row 2969 due to NaN audience: SU04, 농구, 2024-03-28
# Skipping row 2970 due to NaN audience: SO07, 농구, 2024-03-28
# Skipping row 2971 due to NaN audience: BS03, 농구, 2024-03-29
# Skipping row 2972 due to NaN audience: US04, 농구, 2024-03-31
# Skipping row 2973 due to NaN audience: BS03, 농구, 2024-03-31
# Skipping row 2974 due to NaN audience: WJ01, 농구, 2024-03-31
# Skipping row 2975 due to NaN audience: GY01, 농구, 2024-03-31
# Skipping row 2976 due to NaN audience: CW02, 농구, 2024-03-31
# Skipping row 2977 due to NaN audience: SO07, 농구, 2024-04-04
# Skipping row 2978 due to NaN audience: SU04, 농구, 2024-04-05
# Skipping row 2979 due to NaN audience: SO07, 농구, 2024-04-06
# Skipping row 2980 due to NaN audience: SU04, 농구, 2024-04-07
# Skipping row 2981 due to NaN audience: BS03, 농구, 2024-04-08
# Skipping row 2982 due to NaN audience: US04, 농구, 2024-04-09
# Skipping row 2983 due to NaN audience: US04, 농구, 2024-04-11
# Skipping row 2984 due to NaN audience: WJ01, 농구, 2024-04-15
# Skipping row 2985 due to NaN audience: CW02, 농구, 2024-04-16
# Skipping row 2986 due to NaN audience: WJ01, 농구, 2024-04-17
# Skipping row 2987 due to NaN audience: CW02, 농구, 2024-04-18
# Skipping row 2988 due to NaN audience: BS03, 농구, 2024-04-19
# Skipping row 2989 due to NaN audience: SU04, 농구, 2024-04-20
# Skipping row 2990 due to NaN audience: BS03, 농구, 2024-04-21
# Skipping row 2991 due to NaN audience: SU04, 농구, 2024-04-22
# Skipping row 2992 due to NaN audience: CW02, 농구, 2024-04-24
# Skipping row 2993 due to NaN audience: SU04, 농구, 2024-04-27
# Skipping row 2994 due to NaN audience: SU04, 농구, 2024-04-29
# Skipping row 2995 due to NaN audience: BS03, 농구, 2024-05-01
# Skipping row 2996 due to NaN audience: BS03, 농구, 2024-05-03
# Skipping row 2997 due to NaN audience: SU04, 농구, 2024-05-05
# Skipping row 2998 due to NaN audience: BS03, 농구, 2024-10-19
# Skipping row 2999 due to NaN audience: WJ01, 농구, 2024-10-19
# Skipping row 3000 due to NaN audience: CW02, 농구, 2024-10-19
# Skipping row 3001 due to NaN audience: SU04, 농구, 2024-10-20
# Skipping row 3002 due to NaN audience: SO07, 농구, 2024-10-20
# Skipping row 3003 due to NaN audience: US04, 농구, 2024-10-20
# Skipping row 3004 due to NaN audience: CW02, 농구, 2024-10-21
# Skipping row 3005 due to NaN audience: SO07, 농구, 2024-10-22
# Skipping row 3006 due to NaN audience: BS03, 농구, 2024-10-23
# Skipping row 3007 due to NaN audience: WJ01, 농구, 2024-10-24
# Skipping row 3008 due to NaN audience: CW02, 농구, 2024-10-24
# Skipping row 3009 due to NaN audience: BS03, 농구, 2024-10-25
# Skipping row 3010 due to NaN audience: SU04, 농구, 2024-10-25
# Skipping row 3011 due to NaN audience: DG04, 농구, 2024-10-26
# Skipping row 3012 due to NaN audience: GY01, 농구, 2024-10-26
# Skipping row 3013 due to NaN audience: AY01, 농구, 2024-10-26
# Skipping row 3014 due to NaN audience: SO06, 농구, 2024-10-27
# Skipping row 3015 due to NaN audience: SU04, 농구, 2024-10-27
# Skipping row 3016 due to NaN audience: WJ01, 농구, 2024-10-27
# Skipping row 3017 due to NaN audience: GY01, 농구, 2024-10-28
# Skipping row 3018 due to NaN audience: SO06, 농구, 2024-10-29
# Skipping row 3019 due to NaN audience: AY01, 농구, 2024-10-30
# Skipping row 3020 due to NaN audience: GY01, 농구, 2024-10-31
# Skipping row 3021 due to NaN audience: SO06, 농구, 2024-10-31
# Skipping row 3022 due to NaN audience: BS03, 농구, 2024-11-01
# Skipping row 3023 due to NaN audience: CW02, 농구, 2024-11-01
# Skipping row 3024 due to NaN audience: SU04, 농구, 2024-11-02
# Skipping row 3025 due to NaN audience: US04, 농구, 2024-11-02
# Skipping row 3026 due to NaN audience: SO06, 농구, 2024-11-02
# Skipping row 3027 due to NaN audience: CW02, 농구, 2024-11-03
# Skipping row 3028 due to NaN audience: DG04, 농구, 2024-11-03
# Skipping row 3029 due to NaN audience: BS03, 농구, 2024-11-03
# Skipping row 3030 due to NaN audience: WJ01, 농구, 2024-11-04
# Skipping row 3031 due to NaN audience: DG04, 농구, 2024-11-05
# Skipping row 3032 due to NaN audience: US04, 농구, 2024-11-06
# Skipping row 3033 due to NaN audience: SO06, 농구, 2024-11-07
# Skipping row 3034 due to NaN audience: AY01, 농구, 2024-11-07
# Skipping row 3035 due to NaN audience: US04, 농구, 2024-11-08
# Skipping row 3036 due to NaN audience: DG04, 농구, 2024-11-08
# Skipping row 3037 due to NaN audience: SU04, 농구, 2024-11-09
# Skipping row 3038 due to NaN audience: SO07, 농구, 2024-11-09
# Skipping row 3039 due to NaN audience: AY01, 농구, 2024-11-09
# Skipping row 3040 due to NaN audience: WJ01, 농구, 2024-11-10
# Skipping row 3041 due to NaN audience: DG04, 농구, 2024-11-10
# Skipping row 3042 due to NaN audience: SO07, 농구, 2024-11-10
# Skipping row 3043 due to NaN audience: SU04, 농구, 2024-11-11
# Skipping row 3044 due to NaN audience: WJ01, 농구, 2024-11-12
# Skipping row 3045 due to NaN audience: GY01, 농구, 2024-11-13
# Skipping row 3046 due to NaN audience: DG04, 농구, 2024-11-14
# Skipping row 3047 due to NaN audience: CW02, 농구, 2024-11-14
# Skipping row 3048 due to NaN audience: BS03, 농구, 2024-11-27
# Skipping row 3049 due to NaN audience: CW02, 농구, 2024-11-27
# Skipping row 3050 due to NaN audience: SO06, 농구, 2024-11-28
# Skipping row 3051 due to NaN audience: WJ01, 농구, 2024-11-28
# Skipping row 3052 due to NaN audience: SO07, 농구, 2024-11-29
# Skipping row 3053 due to NaN audience: AY01, 농구, 2024-11-29
# Skipping row 3054 due to NaN audience: SU04, 농구, 2024-11-30
# Skipping row 3055 due to NaN audience: GY01, 농구, 2024-11-30
# Skipping row 3056 due to NaN audience: SO06, 농구, 2024-11-30
# Skipping row 3057 due to NaN audience: SO07, 농구, 2024-12-01
# Skipping row 3058 due to NaN audience: GY01, 농구, 2024-12-01
# Skipping row 3059 due to NaN audience: DG04, 농구, 2024-12-01
# Skipping row 3060 due to NaN audience: SO06, 농구, 2024-12-02
# Skipping row 3061 due to NaN audience: DG04, 농구, 2024-12-03
# Skipping row 3062 due to NaN audience: WJ01, 농구, 2024-12-04
# Skipping row 3063 due to NaN audience: US04, 농구, 2024-12-05
# Skipping row 3064 due to NaN audience: DG04, 농구, 2024-12-05
# Skipping row 3065 due to NaN audience: AY01, 농구, 2024-12-06
# Skipping row 3066 due to NaN audience: GY01, 농구, 2024-12-06
# Skipping row 3067 due to NaN audience: US04, 농구, 2024-12-07
# Skipping row 3068 due to NaN audience: SO06, 농구, 2024-12-07
# Skipping row 3069 due to NaN audience: CW02, 농구, 2024-12-07
# Skipping row 3070 due to NaN audience: SU04, 농구, 2024-12-08
# Skipping row 3071 due to NaN audience: GY01, 농구, 2024-12-08
# Skipping row 3072 due to NaN audience: US04, 농구, 2024-12-08
# Skipping row 3073 due to NaN audience: DG04, 농구, 2024-12-09
# Skipping row 3074 due to NaN audience: BS03, 농구, 2024-12-10
# Skipping row 3075 due to NaN audience: AY01, 농구, 2024-12-11
# Skipping row 3076 due to NaN audience: DG04, 농구, 2024-12-12
# Skipping row 3077 due to NaN audience: US04, 농구, 2024-12-12
# Skipping row 3078 due to NaN audience: GY01, 농구, 2024-12-13
# Skipping row 3079 due to NaN audience: AY01, 농구, 2024-12-13
# Skipping row 3080 due to NaN audience: BS03, 농구, 2024-12-14
# Skipping row 3081 due to NaN audience: SU04, 농구, 2024-12-14
# Skipping row 3082 due to NaN audience: SO07, 농구, 2024-12-14
# Skipping row 3083 due to NaN audience: BS03, 농구, 2024-12-15
# Skipping row 3084 due to NaN audience: AY01, 농구, 2024-12-15
# Skipping row 3085 due to NaN audience: SO07, 농구, 2024-12-15
# Skipping row 3086 due to NaN audience: WJ01, 농구, 2024-12-16
# Skipping row 3087 due to NaN audience: CW02, 농구, 2024-12-17
# Skipping row 3088 due to NaN audience: GY01, 농구, 2024-12-18
# Skipping row 3089 due to NaN audience: US04, 농구, 2024-12-19
# Skipping row 3090 due to NaN audience: WJ01, 농구, 2024-12-19
# Skipping row 3091 due to NaN audience: CW02, 농구, 2024-12-20
# Skipping row 3092 due to NaN audience: SU04, 농구, 2024-12-20
# Skipping row 3093 due to NaN audience: GY01, 농구, 2024-12-21
# Skipping row 3094 due to NaN audience: AY01, 농구, 2024-12-21
# Skipping row 3095 due to NaN audience: WJ01, 농구, 2024-12-21
# Skipping row 3096 due to NaN audience: BS03, 농구, 2024-12-22
# Skipping row 3097 due to NaN audience: AY01, 농구, 2024-12-22
# Skipping row 3098 due to NaN audience: WJ01, 농구, 2024-12-22
# Skipping row 3099 due to NaN audience: SU04, 농구, 2024-12-24
# Skipping row 3100 due to NaN audience: BS03, 농구, 2024-12-25
# Skipping row 3101 due to NaN audience: GY01, 농구, 2024-12-25
# Skipping row 3102 due to NaN audience: SO07, 농구, 2024-12-25
# Skipping row 3103 due to NaN audience: DG04, 농구, 2024-12-26
# Skipping row 3104 due to NaN audience: BS03, 농구, 2024-12-27
# Skipping row 3105 due to NaN audience: WJ01, 농구, 2024-12-27
# Skipping row 3106 due to NaN audience: CW02, 농구, 2024-12-28
# Skipping row 3107 due to NaN audience: DG04, 농구, 2024-12-28
# Skipping row 3108 due to NaN audience: AY01, 농구, 2024-12-28
# Skipping row 3109 due to NaN audience: CW02, 농구, 2024-12-29
# Skipping row 3110 due to NaN audience: US04, 농구, 2024-12-29
# Skipping row 3111 due to NaN audience: BS03, 농구, 2024-12-29
# Skipping row 3112 due to NaN audience: US04, 농구, 2024-12-31
# Skipping row 3185 due to NaN audience: GM01, 배구, 2023-08-06
# Skipping row 3186 due to NaN audience: GM01, 배구, 2023-08-06
# Skipping row 3187 due to NaN audience: GM01, 배구, 2023-08-07
# Skipping row 3188 due to NaN audience: GM01, 배구, 2023-08-07
# Skipping row 3189 due to NaN audience: GM01, 배구, 2023-08-08
# Skipping row 3190 due to NaN audience: GM01, 배구, 2023-08-08
# Skipping row 3191 due to NaN audience: GM01, 배구, 2023-08-09
# Skipping row 3192 due to NaN audience: GM01, 배구, 2023-08-09
# Skipping row 3193 due to NaN audience: GM01, 배구, 2023-08-10
# Skipping row 3194 due to NaN audience: GM01, 배구, 2023-08-10
# Skipping row 3195 due to NaN audience: GM01, 배구, 2023-08-11
# Skipping row 3196 due to NaN audience: GM01, 배구, 2023-08-11
# Skipping row 3197 due to NaN audience: GM01, 배구, 2023-08-12
# Skipping row 3198 due to NaN audience: GM01, 배구, 2023-08-12
# Skipping row 3199 due to NaN audience: GM01, 배구, 2023-08-13
# Skipping row 3467 due to NaN audience: GM01, 여자배구, 2023-07-29
# Skipping row 3468 due to NaN audience: GM01, 여자배구, 2023-07-29
# Skipping row 3469 due to NaN audience: GM01, 여자배구, 2023-07-30
# Skipping row 3470 due to NaN audience: GM01, 여자배구, 2023-07-30
# Skipping row 3471 due to NaN audience: GM01, 여자배구, 2023-07-31
# Skipping row 3472 due to NaN audience: GM01, 여자배구, 2023-07-31
# Skipping row 3473 due to NaN audience: GM01, 여자배구, 2023-08-01
# Skipping row 3474 due to NaN audience: GM01, 여자배구, 2023-08-01
# Skipping row 3475 due to NaN audience: GM01, 여자배구, 2023-08-02
# Skipping row 3476 due to NaN audience: GM01, 여자배구, 2023-08-02
# Skipping row 3477 due to NaN audience: GM01, 여자배구, 2023-08-03
# Skipping row 3478 due to NaN audience: GM01, 여자배구, 2023-08-03
# Skipping row 3479 due to NaN audience: GM01, 여자배구, 2023-08-04
# Skipping row 3480 due to NaN audience: GM01, 여자배구, 2023-08-04
# Skipping row 3481 due to NaN audience: GM01, 여자배구, 2023-08-05
# --- 업데이트 완료 ---
# 총 2902 개의 행의 audience 정보가 DB에 반영(또는 시도)되었습니다.
# 1078 개의 행은 audience 값이 NaN/NA 여서 건너뛰었습니다.

# %%
# 데이터베이스 연결 종료
if 'engine' in locals() and engine:
    engine.dispose()
    print("\n데이터베이스 연결이 종료되었습니다.")
# Out:
# 데이터베이스 연결이 종료되었습니다.
