# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set Korean font for matplotlib
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False # To display minus sign correctly

df = pd.read_csv('./results/2nd-dataset_전국_20250605_022817.csv')

print("--- 1. Initial Data Inspection ---")
print("Shape of the dataframe:", df.shape)
print("\nFirst 5 rows:")
print(df.head())
print("\nData types and non-null counts:")
df.info()
print("\nSummary statistics for numerical columns:")
print(df.describe())
print("\nSummary statistics for object columns:")
print(df.describe(include='object'))
print("\nMissing values per column:")
print(df.isnull().sum())

print("\n--- 2. Data Cleaning and Preprocessing ---")
# Convert 'date' to datetime objects
df['date'] = pd.to_datetime(df['date'])

# Convert boolean-like columns to actual booleans for clarity if needed (0/1 is fine for most analyses)
df['is_post_season'] = df['is_post_season'].astype(bool)
df['is_holiday'] = df['is_holiday'].astype(bool)

# Create a column 'has_game' for easier filtering
df['has_game'] = df['game_count'] > 0

# Check consistency: region_code
print("\nUnique values in 'region_code':", df['region_code'].unique())
# If 'region_code' is constant, we might drop it for modeling, but keep for EDA context.

# Clean sports_types: "없음" means no sport, otherwise it's a list
# For analysis, we can create dummy variables for common sports
all_sports = set()
for sports_list in df['sports_types'].unique():
    if sports_list != "없음":
        for sport in sports_list.split(','):
            all_sports.add(sport.strip()) # .strip() to remove potential leading/trailing spaces

print("\nIdentified unique sport types:", sorted(list(all_sports)))

# Create boolean columns for each identified sport
for sport in sorted(list(all_sports)):
    df[f'is_{sport}'] = df['sports_types'].apply(lambda x: sport in x)

print("\nDataFrame with new sport boolean columns (first 5 rows):")
print(df.head())


print("\n--- 3. Feature Engineering (Time-based features) ---")
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['day_of_week_num'] = df['date'].dt.dayofweek # Monday=0, Sunday=6

print("\n--- 4. Univariate Analysis ---")

# 4.1 Distribution of Accident Count
plt.figure(figsize=(10, 5))
sns.histplot(df['accident_count'], kde=True, bins=20)
plt.title('Distribution of Daily Accident Counts')
plt.xlabel('Number of Accidents')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 4))
sns.boxplot(x=df['accident_count'])
plt.title('Box Plot of Daily Accident Counts')
plt.xlabel('Number of Accidents')
plt.grid(True)
plt.show()
print(f"Accident count statistics:\n{df['accident_count'].describe()}")

# 4.2 Distribution of Numerical Weather Features
weather_cols = ['temperature', 'precipitation', 'snow_depth']
for col in weather_cols:
    plt.figure(figsize=(10, 5))
    sns.histplot(df[col], kde=True, bins=20)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()
    print(f"{col} statistics:\n{df[col].describe()}")

# 4.3 Counts of Categorical Features
categorical_cols = ['is_hometeam_win', 'game_count', 'is_post_season', 'weather_condition', 'is_holiday', 'weekday', 'has_game']
for col in categorical_cols:
    plt.figure(figsize=(10, 5))
    sns.countplot(y=df[col], order = df[col].value_counts().index) # y for better label readability
    plt.title(f'Counts of {col}')
    plt.xlabel('Count')
    plt.ylabel(col)
    plt.grid(axis='x')
    plt.show()
    print(f"\nValue counts for {col}:\n{df[col].value_counts(normalize=True)*100} %")

# 4.4 Sport Types Distribution (among days with games)
sport_counts = {}
for sport in sorted(list(all_sports)):
    sport_counts[sport] = df[f'is_{sport}'].sum()

plt.figure(figsize=(12, 6))
pd.Series(sport_counts).sort_values(ascending=False).plot(kind='bar')
plt.title('Number of Days Each Sport Was Played')
plt.ylabel('Number of Days')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y')
plt.tight_layout()
plt.show()


print("\n--- 5. Bivariate and Multivariate Analysis ---")

# 5.1 Accident Count vs. Time Features
# Monthly
plt.figure(figsize=(12, 6))
sns.boxplot(x='month', y='accident_count', data=df)
plt.title('Accident Counts by Month')
plt.xlabel('Month')
plt.ylabel('Accident Count')
plt.grid(True)
plt.show()

# Day of the week
weekday_order = ['월', '화', '수', '목', '금', '토', '일']
plt.figure(figsize=(10, 6))
sns.boxplot(x='weekday', y='accident_count', data=df, order=weekday_order)
plt.title('Accident Counts by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Accident Count')
plt.grid(True)
plt.show()

# Year (if multiple years exist)
if df['year'].nunique() > 1:
    plt.figure(figsize=(8, 5))
    sns.boxplot(x='year', y='accident_count', data=df)
    plt.title('Accident Counts by Year')
    plt.xlabel('Year')
    plt.ylabel('Accident Count')
    plt.grid(True)
    plt.show()

# 5.2 Accident Count vs. Game-Related Features
# Has Game?
plt.figure(figsize=(8, 5))
sns.boxplot(x='has_game', y='accident_count', data=df)
plt.title('Accident Counts: Game Day vs. No Game Day')
plt.xlabel('Was there a game?')
plt.ylabel('Accident Count')
plt.xticks([0, 1], ['No Game', 'Game'])
plt.grid(True)
plt.show()
print(df.groupby('has_game')['accident_count'].describe())

# Game Count (for days with games)
plt.figure(figsize=(10, 6))
sns.boxplot(x='game_count', y='accident_count', data=df[df['has_game']]) # Only for days with games
plt.title('Accident Counts by Number of Games Played (on game days)')
plt.xlabel('Number of Games')
plt.ylabel('Accident Count')
plt.grid(True)
plt.show()

# Has Playoff? (for days with games)
plt.figure(figsize=(8, 5))
sns.boxplot(x='is_post_season', y='accident_count', data=df[df['has_game']]) # Only for days with games
plt.title('Accident Counts: Playoff Game vs. Regular Game (on game days)')
plt.xlabel('Is it a Playoff Game?')
plt.ylabel('Accident Count')
plt.xticks([0, 1], ['Regular Game', 'Playoff Game'])
plt.grid(True)
plt.show()
print(df[df['has_game']].groupby('is_post_season')['accident_count'].describe())

# Specific sports
sports_accidents_mean = {}
for sport in sorted(list(all_sports)):
    sports_accidents_mean[sport] = df[df[f'is_{sport}']]['accident_count'].mean()

plt.figure(figsize=(12, 6))
pd.Series(sports_accidents_mean).sort_values(ascending=False).plot(kind='bar')
plt.title('Average Accident Count on Days When Specific Sport Was Played')
plt.ylabel('Average Accident Count')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y')
plt.axhline(df[df['has_game']==False]['accident_count'].mean(), color='red', linestyle='--', label='Avg Accidents (No Game)')
plt.legend()
plt.tight_layout()
plt.show()

# 5.3 Accident Count vs. Weather Features
# Temperature
plt.figure(figsize=(10, 6))
sns.scatterplot(x='temperature', y='accident_count', data=df, alpha=0.5)
plt.title('Accident Count vs. Temperature')
plt.xlabel('Temperature (°C)')
plt.ylabel('Accident Count')
plt.grid(True)
plt.show()

# Precipitation
plt.figure(figsize=(10, 6))
sns.scatterplot(x='precipitation', y='accident_count', data=df[df['precipitation'] > 0], alpha=0.5)
plt.title('Accident Count vs. Precipitation (for days with precipitation > 0)')
plt.xlabel('Precipitation (mm)')
plt.ylabel('Accident Count')
plt.xscale('log') # Using log scale due to skewness
plt.grid(True)
plt.show()

# Snow Depth
plt.figure(figsize=(10, 6))
sns.scatterplot(x='snow_depth', y='accident_count', data=df[df['snow_depth'] > 0], alpha=0.5)
plt.title('Accident Count vs. Snow Depth (for days with snow_depth > 0)')
plt.xlabel('Snow Depth (cm)')
plt.ylabel('Accident Count')
plt.xscale('log') # Using log scale due to skewness
plt.grid(True)
plt.show()

# Weather Condition
plt.figure(figsize=(12, 7))
weather_order = df.groupby('weather_condition')['accident_count'].mean().sort_values(ascending=False).index
sns.boxplot(x='weather_condition', y='accident_count', data=df, order=weather_order)
plt.title('Accident Counts by Weather Condition')
plt.xlabel('Weather Condition')
plt.ylabel('Accident Count')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.tight_layout()
plt.show()
print(df.groupby('weather_condition')['accident_count'].describe())

# 5.4 Accident Count vs. Holiday
plt.figure(figsize=(8, 5))
sns.boxplot(x='is_holiday', y='accident_count', data=df)
plt.title('Accident Counts: Holiday vs. Non-Holiday')
plt.xlabel('Is it a Holiday?')
plt.ylabel('Accident Count')
plt.xticks([0, 1], ['Non-Holiday', 'Holiday'])
plt.grid(True)
plt.show()
print(df.groupby('is_holiday')['accident_count'].describe())


# 5.5 Correlation Heatmap
numerical_cols_for_corr = ['accident_count', 'audience', 'injury_count','death_count', 'game_count', 'temperature', 'precipitation', 'snow_depth', 'month', 'day_of_week_num']
# Add boolean columns (0/1) for correlation
numerical_cols_for_corr.extend(['is_post_season', 'is_holiday', 'has_game'])
for sport in sorted(list(all_sports)):
    numerical_cols_for_corr.append(f'is_{sport}')

correlation_matrix = df[numerical_cols_for_corr].corr()
plt.figure(figsize=(18, 15)) # Adjust size as needed
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix of Numerical and Boolean Features')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

print("\n--- 6. Time Series Analysis of Accident Counts ---")
plt.figure(figsize=(18, 6))
df.set_index('date')['accident_count'].plot()
plt.title('Daily Accident Counts Over Time')
plt.xlabel('Date')
plt.ylabel('Accident Count')
plt.grid(True)
plt.show()

# Monthly average accident count
monthly_avg_accidents = df.set_index('date').resample('ME')['accident_count'].mean()
plt.figure(figsize=(18, 6))
monthly_avg_accidents.plot(marker='o')
plt.title('Monthly Average Accident Counts Over Time')
plt.xlabel('Month')
plt.ylabel('Average Accident Count')
plt.grid(True)
plt.show()

print("\n--- 7. Combined Effects (Examples) ---")

# 7.1 Game Day vs. No Game Day by Weather Condition
plt.figure(figsize=(14, 7))
sns.boxplot(x='weather_condition', y='accident_count', hue='has_game', data=df, order=weather_order)
plt.title('Accident Counts by Weather Condition, Split by Game Presence')
plt.xlabel('Weather Condition')
plt.ylabel('Accident Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Game Day')
plt.grid(True)
plt.tight_layout()
plt.show()

# 7.2 Playoff vs. Regular Game by Weather (on game days)
if df['has_game'].any(): # Ensure there are game days
    plt.figure(figsize=(14, 7))
    sns.boxplot(x='weather_condition', y='accident_count', hue='is_post_season', 
                data=df[df['has_game']], order=weather_order)
    plt.title('Accident Counts on Game Days by Weather, Split by Playoff Status')
    plt.xlabel('Weather Condition')
    plt.ylabel('Accident Count')
    plt.xticks(rotation=45, ha='right')
    plt.legend(title='Playoff Game')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# 7.3 Precipitation effect on game days vs non-game days
df['has_precipitation'] = df['precipitation'] > 0
plt.figure(figsize=(10, 6))
sns.barplot(x='has_game', y='accident_count', hue='has_precipitation', data=df)
plt.title('Impact of Precipitation on Accident Counts (Game vs. No Game)')
plt.xlabel('Was there a game?')
plt.xticks([0,1], ['No Game', 'Game Day'])
plt.ylabel('Average Accident Count')
plt.legend(title='Has Precipitation')
plt.grid(axis='y')
plt.show()

# 7.4 Snow effect on game days vs non-game days
df['has_snow'] = df['snow_depth'] > 0
plt.figure(figsize=(10, 6))
sns.barplot(x='has_game', y='accident_count', hue='has_snow', data=df)
plt.title('Impact of Snow on Accident Counts (Game vs. No Game)')
plt.xlabel('Was there a game?')
plt.xticks([0,1], ['No Game', 'Game Day'])
plt.ylabel('Average Accident Count')
plt.legend(title='Has Snow')
plt.grid(axis='y')
plt.show()


print("\n--- 8. Focus on Extreme Accident Days ---")
# What are the conditions on days with very high accident counts?
high_accident_threshold = df['accident_count'].quantile(0.90) # Top 10%
high_accident_days = df[df['accident_count'] >= high_accident_threshold]
print(f"\nDays with accident_count >= {high_accident_threshold} (Top 10%):\n")
print(high_accident_days[['date', 'accident_count', 'game_count', 'sports_types', 'is_post_season', 'temperature', 'precipitation', 'snow_depth', 'weather_condition', 'is_holiday', 'weekday']].sort_values(by='accident_count', ascending=False))

print("\nWeather conditions on high accident days:")
print(high_accident_days['weather_condition'].value_counts(normalize=True)*100)

print("\nGame presence on high accident days:")
print(high_accident_days['has_game'].value_counts(normalize=True)*100)

print("\nPlayoff presence on high accident (game) days:")
if high_accident_days['has_game'].any():
    print(high_accident_days[high_accident_days['has_game']]['is_post_season'].value_counts(normalize=True)*100)

print("\nEDA Complete!")
# Out:
# --- 1. Initial Data Inspection ---
# Shape of the dataframe: (28509, 19)
#
# First 5 rows:
#          date  region  accident_count  injury_count  death_count  game_count  \
# 0  2023-01-01     NaN               0             0            0           0
# 1  2023-01-01     NaN               0             0            0           0
# 2  2023-01-01     NaN               0             0            0           0
# 3  2023-01-01     NaN               0             0            0           0
# 4  2023-01-01     NaN               0             0            0           0
#
#   sports_types  temperature  precipitation  snow_depth weather_condition  \
# 0           없음         -2.5            0.0         0.0              정보없음
# 1           없음         -2.1            0.0         0.0                맑음
# 2           없음         -0.2            0.0         0.0              정보없음
# 3           없음          0.3            0.0         0.0                맑음
# 4           없음          0.3            0.0         0.0                맑음
#
#    is_post_season  is_hometeam_win  is_holiday weekday  audience  \
# 0               0              NaN           1       일       NaN
# 1               0              NaN           1       일       NaN
# 2               0              NaN           1       일       NaN
# 3               0              NaN           1       일       NaN
# 4               0              NaN           1       일       NaN
#
#   game_start_time game_end_time region_code
# 0             NaN           NaN      경북 김천시
# 1             NaN           NaN      강원 춘천시
# 2             NaN           NaN      경기 김포시
# 3             NaN           NaN      서울 구로구
# 4             NaN           NaN       서울 중구
#
# Data types and non-null counts:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28509 entries, 0 to 28508
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               28509 non-null  object
#  1   region             0 non-null      float64
#  2   accident_count     28509 non-null  int64
#  3   injury_count       28509 non-null  int64
#  4   death_count        28509 non-null  int64
#  5   game_count         28509 non-null  int64
#  6   sports_types       28509 non-null  object
#  7   temperature        27575 non-null  float64
#  8   precipitation      27581 non-null  float64
#  9   snow_depth         27581 non-null  float64
#  10  weather_condition  28312 non-null  object
#  11  is_post_season     28509 non-null  int64
#  12  is_hometeam_win    263 non-null    float64
#  13  is_holiday         28509 non-null  int64
#  14  weekday            28509 non-null  object
#  15  audience           158 non-null    float64
#  16  game_start_time    263 non-null    object
#  17  game_end_time      263 non-null    object
#  18  region_code        28509 non-null  object
# dtypes: float64(6), int64(6), object(7)
# memory usage: 4.1+ MB
#
# Summary statistics for numerical columns:
#        region  accident_count  injury_count   death_count    game_count  \
# count     0.0    28509.000000  28509.000000  28509.000000  28509.000000
# mean      NaN        4.245431      6.052475      0.040584      0.127363
# std       NaN        3.908028      6.000349      0.216647      0.373012
# min       NaN        0.000000      0.000000      0.000000      0.000000
# 25%       NaN        1.000000      2.000000      0.000000      0.000000
# 50%       NaN        3.000000      5.000000      0.000000      0.000000
# 75%       NaN        6.000000      9.000000      0.000000      0.000000
# max       NaN       33.000000     67.000000      9.000000      4.000000
#
#         temperature  precipitation    snow_depth  is_post_season  \
# count  27575.000000   27581.000000  27581.000000    28509.000000
# mean      14.546020       4.055669      4.055669        0.006033
# std        9.989074      14.724670     14.724670        0.077440
# min      -14.400000       0.000000      0.000000        0.000000
# 25%        5.800000       0.000000      0.000000        0.000000
# 50%       15.700000       0.000000      0.000000        0.000000
# 75%       23.400000       0.500000      0.500000        0.000000
# max       33.500000     414.400000    414.400000        1.000000
#
#        is_hometeam_win    is_holiday      audience
# count       263.000000  28509.000000    158.000000
# mean          0.524715      0.325581  11878.113924
# std           0.500341      0.468600   6554.853537
# min           0.000000      0.000000   2069.000000
# 25%           0.000000      0.000000   6245.250000
# 50%           1.000000      0.000000  10971.000000
# 75%           1.000000      1.000000  16533.250000
# max           1.000000      1.000000  24000.000000
#
# Summary statistics for object columns:
#               date sports_types weather_condition weekday  game_start_time  \
# count        28509        28509             28312   28509              263
# unique         731           18                 5       7                5
# top     2023-01-01           없음                 비       일  0 days 18:30:00
# freq            39        25202              7954    4095              117
#
#           game_end_time region_code
# count               263       28509
# unique                5          39
# top     0 days 21:30:00      경북 김천시
# freq                117         731
#
# Missing values per column:
# date                     0
# region               28509
# accident_count           0
# injury_count             0
# death_count              0
# game_count               0
# sports_types             0
# temperature            934
# precipitation          928
# snow_depth             928
# weather_condition      197
# is_post_season           0
# is_hometeam_win      28246
# is_holiday               0
# weekday                  0
# audience             28351
# game_start_time      28246
# game_end_time        28246
# region_code              0
# dtype: int64
#
# --- 2. Data Cleaning and Preprocessing ---
#
# Unique values in 'region_code': ['경북 김천시' '강원 춘천시' '경기 김포시' '서울 구로구' '서울 중구' '경기 안양시' '대구 동구' '울산 남구'
#  '경기 고양시' '경남 창원시' '경기 이천시' '경기 의정부시' '인천 계양구' '인천 미추홀구' '서울 양천구' '부산 동래구'
#  '부산 연제구' '대전 중구' '서울 마포구' '제주 제주시' '인천 남동구' '경북 구미시' '인천 서구' '전북 군산시'
#  '강원 원주시' '광주 북구' '울산 중구' '대구 수성구' '전북 전주시' '대전 유성구' '서울 송파구' '광주 광산구'
#  '강원 강릉시' '경북 포항시' '경기 화성시' '충남 천안시' '충북 청주시' '경기 안산시' '경기 수원시']
#
# Identified unique sport types: ['농구', '배구', '야구', '여자배구', '축구']
#
# DataFrame with new sport boolean columns (first 5 rows):
#         date  region  accident_count  injury_count  death_count  game_count  \
# 0 2023-01-01     NaN               0             0            0           0
# 1 2023-01-01     NaN               0             0            0           0
# 2 2023-01-01     NaN               0             0            0           0
# 3 2023-01-01     NaN               0             0            0           0
# 4 2023-01-01     NaN               0             0            0           0
#
#   sports_types  temperature  precipitation  snow_depth  ... audience  \
# 0           없음         -2.5            0.0         0.0  ...      NaN
# 1           없음         -2.1            0.0         0.0  ...      NaN
# 2           없음         -0.2            0.0         0.0  ...      NaN
# 3           없음          0.3            0.0         0.0  ...      NaN
# 4           없음          0.3            0.0         0.0  ...      NaN
#
#    game_start_time  game_end_time  region_code has_game  is_농구  is_배구  is_야구  \
# 0              NaN            NaN       경북 김천시    False  False  False  False
# 1              NaN            NaN       강원 춘천시    False  False  False  False
# 2              NaN            NaN       경기 김포시    False  False  False  False
# 3              NaN            NaN       서울 구로구    False  False  False  False
# 4              NaN            NaN        서울 중구    False  False  False  False
#
#   is_여자배구  is_축구
# 0   False  False
# 1   False  False
# 2   False  False
# 3   False  False
# 4   False  False
#
# [5 rows x 25 columns]
#
# --- 3. Feature Engineering (Time-based features) ---
#
# --- 4. Univariate Analysis ---
# Accident count statistics:
# count    28509.000000
# mean         4.245431
# std          3.908028
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          6.000000
# max         33.000000
# Name: accident_count, dtype: float64
# temperature statistics:
# count    27575.000000
# mean        14.546020
# std          9.989074
# min        -14.400000
# 25%          5.800000
# 50%         15.700000
# 75%         23.400000
# max         33.500000
# Name: temperature, dtype: float64
# precipitation statistics:
# count    27581.000000
# mean         4.055669
# std         14.724670
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.500000
# max        414.400000
# Name: precipitation, dtype: float64
# snow_depth statistics:
# count    27581.000000
# mean         4.055669
# std         14.724670
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.500000
# max        414.400000
# Name: snow_depth, dtype: float64
# Value counts for is_hometeam_win:
# is_hometeam_win
# 1.0    52.471483
# 0.0    47.528517
# Name: proportion, dtype: float64 %
# Value counts for game_count:
# game_count
# 0    88.400154
# 1    10.719422
# 2     0.631380
# 3     0.242029
# 4     0.007015
# Name: proportion, dtype: float64 %
# Value counts for is_post_season:
# is_post_season
# False    99.396682
# True      0.603318
# Name: proportion, dtype: float64 %
# Value counts for weather_condition:
# weather_condition
# 비       28.094094
# 약간흐림    24.254733
# 맑음      24.152303
# 정보없음    15.696524
# 흐림       7.802345
# Name: proportion, dtype: float64 %
# Value counts for is_holiday:
# is_holiday
# False    67.44186
# True     32.55814
# Name: proportion, dtype: float64 %
# Value counts for weekday:
# weekday
# 일    14.363885
# 월    14.363885
# 화    14.363885
# 수    14.227086
# 목    14.227086
# 금    14.227086
# 토    14.227086
# Name: proportion, dtype: float64 %
# Value counts for has_game:
# has_game
# False    88.400154
# True     11.599846
# Name: proportion, dtype: float64 %
# --- 5. Bivariate and Multivariate Analysis ---
#             count      mean       std  min  25%  50%  75%   max
# has_game
# False     25202.0  4.179430  3.840655  0.0  1.0  3.0  6.0  33.0
# True       3307.0  4.748412  4.355521  0.0  1.0  4.0  7.0  27.0
#                  count      mean       std  min  25%  50%  75%   max
# is_post_season
# False           3135.0  4.718341  4.343143  0.0  1.0  4.0  7.0  27.0
# True             172.0  5.296512  4.553694  0.0  2.0  4.0  8.0  19.0
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
#                     count      mean       std  min  25%  50%  75%   max
# weather_condition
# 맑음                 6838.0  4.297748  3.748020  0.0  2.0  3.0  6.0  32.0
# 비                  7954.0  4.331657  3.941817  0.0  1.0  3.0  6.0  33.0
# 약간흐림               6867.0  4.327363  3.643526  0.0  2.0  4.0  6.0  27.0
# 정보없음               4444.0  4.192844  4.615871  0.0  0.0  3.0  8.0  26.0
# 흐림                 2209.0  3.993662  3.436531  0.0  1.0  3.0  6.0  23.0
#               count      mean       std  min  25%  50%  75%   max
# is_holiday
# False       19227.0  4.566391  4.098915  0.0  2.0  4.0  7.0  33.0
# True         9282.0  3.580586  3.384179  0.0  1.0  3.0  5.0  27.0
# --- 6. Time Series Analysis of Accident Counts ---
# --- 7. Combined Effects (Examples) ---
# --- 8. Focus on Extreme Accident Days ---
#
# Days with accident_count >= 10.0 (Top 10%):
#
#             date  accident_count  game_count sports_types  is_post_season  \
# 27182 2024-11-27              33           0           없음           False
# 15170 2024-01-24              32           0           없음           False
# 15131 2024-01-23              28           0           없음           False
# 20045 2024-05-28              27           0           없음           False
# 15287 2024-01-27              27           1           농구           False
# ...          ...             ...         ...          ...             ...
# 9006  2023-08-19              10           0           없음           False
# 23667 2024-08-29              10           0           없음           False
# 19925 2024-05-25              10           0           없음           False
# 15325 2024-01-28              10           0           없음           False
# 36    2023-01-01              10           0           없음           False
#
#        temperature  precipitation  snow_depth weather_condition  is_holiday  \
# 27182          0.2           27.8        27.8                 비       False
# 15170         -7.5            0.0         0.0                맑음       False
# 15131        -10.8            0.0         0.0                맑음       False
# 20045         18.9            0.0         0.0                맑음       False
# 15287         -1.5            0.0         0.0                맑음        True
# ...            ...            ...         ...               ...         ...
# 9006          27.7            0.0         0.0                맑음        True
# 23667         29.0            0.0         0.0                맑음       False
# 19925         19.6            0.0         0.0                흐림        True
# 15325         -1.2            0.0         0.0              약간흐림        True
# 36            -0.4            0.0         0.0                맑음        True
#
#       weekday
# 27182       수
# 15170       수
# 15131       화
# 20045       화
# 15287       토
# ...       ...
# 9006        토
# 23667       목
# 19925       토
# 15325       일
# 36          일
#
# [2868 rows x 11 columns]
#
# Weather conditions on high accident days:
# weather_condition
# 비       28.705964
# 정보없음    23.194977
# 약간흐림    21.695152
# 맑음      20.892919
# 흐림       5.510987
# Name: proportion, dtype: float64
#
# Game presence on high accident days:
# has_game
# False    84.449093
# True     15.550907
# Name: proportion, dtype: float64
#
# Playoff presence on high accident (game) days:
# is_post_season
# False    93.049327
# True      6.950673
# Name: proportion, dtype: float64
#
# EDA Complete!

# %%
df_encoded = pd.get_dummies(df, columns=['weather_condition'], drop_first=True)

# %%
df_encoded.columns
# Out:
# Index(['date', 'region', 'accident_count', 'injury_count', 'death_count',
#        'game_count', 'sports_types', 'temperature', 'precipitation',
#        'snow_depth', 'is_post_season', 'is_hometeam_win', 'is_holiday',
#        'weekday', 'audience', 'game_start_time', 'game_end_time',
#        'region_code', 'has_game', 'is_농구', 'is_배구', 'is_야구', 'is_여자배구',
#        'is_축구', 'year', 'month', 'day_of_week_num', 'has_precipitation',
#        'has_snow', 'weather_condition_비', 'weather_condition_약간흐림',
#        'weather_condition_정보없음', 'weather_condition_흐림'],
#       dtype='object')

# %%
for col in df_encoded.columns:
    if df_encoded[col].nunique() == 1:
        print(f"Dropping constant column: {col}")
        df_encoded = df_encoded.drop(columns=[col])

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import numpy as np

#formula = """accident_count ~ game_count + accident_count + injury_count + death_count + 
#            temperature + precipitation + snow_depth + is_holiday + is_post_season +
#            is_hometeam_win + audience + is_농구 + is_배구 + is_야구 + is_여자배구 + is_축구 +
#            weather_condition_약간흐림 + weather_condition_비 + weather_condition_흐림 + 
#            day_of_week_num"""

formula = """accident_count ~ is_post_season + audience + injury_count + temperature + precipitation + is_holiday +
            is_hometeam_win + is_농구 + is_배구 + is_야구 + is_여자배구 + is_축구 +
            weather_condition_약간흐림 + weather_condition_비 + weather_condition_흐림 + day_of_week_num
            """

model = smf.glm(formula=formula, data=df_encoded, family=sm.families.Poisson()).fit(cov_type='HC1')
print(model.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:         accident_count   No. Observations:                  158
# Model:                            GLM   Df Residuals:                      141
# Model Family:                 Poisson   Df Model:                           16
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -350.91
# Date:                    목, 05 6 2025   Deviance:                       216.97
# Time:                        03:18:33   Pearson chi2:                     160.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.9321
# Covariance Type:                  HC1
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.5904      0.310      1.908      0.056      -0.016       1.197
# is_post_season[T.True]             0.1050      0.172      0.612      0.540      -0.231       0.441
# is_holiday[T.True]                -0.0287      0.124     -0.232      0.817      -0.271       0.214
# is_농구[T.True]                      0.2433      0.253      0.962      0.336      -0.253       0.739
# is_배구[T.True]                      0.1088      0.213      0.510      0.610      -0.309       0.527
# is_야구[T.True]                      0.3021      0.254      1.188      0.235      -0.196       0.800
# is_여자배구[T.True]                    0.6418      0.271      2.365      0.018       0.110       1.174
# is_축구[T.True]                      0.2558      0.176      1.454      0.146      -0.089       0.601
# weather_condition_약간흐림[T.True]    -0.0327      0.078     -0.419      0.675      -0.186       0.120
# weather_condition_비[T.True]       -0.2225      0.106     -2.101      0.036      -0.430      -0.015
# weather_condition_흐림[T.True]      -0.1311      0.113     -1.165      0.244      -0.352       0.090
# audience                        1.102e-05   5.43e-06      2.030      0.042    3.79e-07    2.17e-05
# injury_count                       0.0856      0.008     10.450      0.000       0.070       0.102
# temperature                       -0.0033      0.005     -0.607      0.544      -0.014       0.007
# precipitation                      0.0055      0.003      1.936      0.053   -6.81e-05       0.011
# is_hometeam_win                    0.0336      0.070      0.483      0.629      -0.103       0.170
# day_of_week_num                   -0.0054      0.037     -0.145      0.884      -0.079       0.068
# ==================================================================================================

# %%
game_day_baseball = df_encoded[df_encoded['is_야구']]
no_game_day_baseball = df_encoded[~df_encoded['is_야구']]

formula = """accident_count ~ is_post_season + audience + injury_count + temperature + precipitation + is_holiday +
            is_hometeam_win + weather_condition_약간흐림 + weather_condition_비 + weather_condition_흐림 + day_of_week_num
            """

model = smf.glm(formula=formula, data=game_day_baseball, family=sm.families.Poisson()).fit(cov_type='HC1')
print(model.summary())

formula = """accident_count ~ injury_count + temperature + precipitation + is_holiday +
            weather_condition_약간흐림 + weather_condition_비 + weather_condition_흐림 + day_of_week_num
            """

model = smf.glm(formula=formula, data=no_game_day_baseball, family=sm.families.Poisson()).fit(cov_type='HC1')
print(model.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:         accident_count   No. Observations:                  132
# Model:                            GLM   Df Residuals:                      120
# Model Family:                 Poisson   Df Model:                           11
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -293.02
# Date:                    목, 05 6 2025   Deviance:                       184.57
# Time:                        03:18:36   Pearson chi2:                     134.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.9193
# Covariance Type:                  HC1
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.9202      0.195      4.727      0.000       0.539       1.302
# is_post_season[T.True]             0.0964      0.159      0.607      0.544      -0.215       0.408
# is_holiday[T.True]                 0.0614      0.116      0.529      0.597      -0.166       0.289
# weather_condition_약간흐림[T.True]    -0.0758      0.090     -0.845      0.398      -0.252       0.100
# weather_condition_비[T.True]       -0.1373      0.107     -1.284      0.199      -0.347       0.072
# weather_condition_흐림[T.True]      -0.1834      0.133     -1.383      0.167      -0.443       0.076
# audience                        5.618e-06   5.87e-06      0.957      0.339   -5.89e-06    1.71e-05
# injury_count                       0.0846      0.009      9.721      0.000       0.068       0.102
# temperature                       -0.0024      0.006     -0.426      0.670      -0.013       0.009
# precipitation                      0.0043      0.003      1.634      0.102      -0.001       0.009
# is_hometeam_win                    0.0323      0.074      0.436      0.663      -0.113       0.177
# day_of_week_num                   -0.0067      0.038     -0.177      0.860      -0.081       0.067
# ==================================================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:         accident_count   No. Observations:                25774
# Model:                            GLM   Df Residuals:                    25765
# Model Family:                 Poisson   Df Model:                            8
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -52752.
# Date:                    목, 05 6 2025   Deviance:                       36055.
# Time:                        03:18:36   Pearson chi2:                 2.67e+04
# No. Iterations:                     6   Pseudo R-squ. (CS):             0.8848
# Covariance Type:                  HC1
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.7389      0.021     35.001      0.000       0.697       0.780
# is_holiday[T.True]                -0.1998      0.016    -12.801      0.000      -0.230      -0.169
# weather_condition_약간흐림[T.True]     0.0950      0.015      6.323      0.000       0.066       0.124
# weather_condition_비[T.True]        0.0589      0.018      3.316      0.001       0.024       0.094
# weather_condition_흐림[T.True]       0.0716      0.015      4.870      0.000       0.043       0.100
# injury_count                       0.0835      0.003     29.152      0.000       0.078       0.089
# temperature                        0.0012      0.001      1.887      0.059   -4.59e-05       0.002
# precipitation                     -0.0007      0.000     -2.079      0.038      -0.001   -4.25e-05
# day_of_week_num                    0.0055      0.004      1.342      0.180      -0.003       0.013
# ==================================================================================================

# %%
game_day_soccer = df_encoded[df_encoded['is_축구']]
no_game_day_soccer = df_encoded[~df_encoded['is_축구']]

formula = """accident_count ~ is_post_season + injury_count + temperature + precipitation + is_holiday +
            weather_condition_약간흐림 + weather_condition_비 + weather_condition_흐림 + day_of_week_num
            """

model = smf.glm(formula=formula, data=game_day_soccer, family=sm.families.Poisson()).fit(cov_type='HC1')
print(model.summary())

formula = """accident_count ~ injury_count + temperature + precipitation + is_holiday +
            weather_condition_약간흐림 + weather_condition_비 + weather_condition_흐림 + day_of_week_num
            """

model = smf.glm(formula=formula, data=no_game_day_soccer, family=sm.families.Poisson()).fit(cov_type='HC1')
print(model.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:         accident_count   No. Observations:                  422
# Model:                            GLM   Df Residuals:                      412
# Model Family:                 Poisson   Df Model:                            9
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -860.16
# Date:                    목, 05 6 2025   Deviance:                       382.59
# Time:                        03:20:41   Pearson chi2:                     331.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.8965
# Covariance Type:                  HC1
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          1.1322      0.103     10.953      0.000       0.930       1.335
# is_post_season[T.True]             0.0025      0.088      0.028      0.978      -0.169       0.174
# is_holiday[T.True]                 0.0267      0.096      0.278      0.781      -0.162       0.215
# weather_condition_약간흐림[T.True]     0.0529      0.063      0.834      0.404      -0.071       0.177
# weather_condition_비[T.True]       -0.0479      0.070     -0.688      0.491      -0.184       0.088
# weather_condition_흐림[T.True]       0.0649      0.065      0.997      0.319      -0.063       0.193
# injury_count                       0.0731      0.004     18.345      0.000       0.065       0.081
# temperature                       -0.0003      0.004     -0.070      0.944      -0.009       0.008
# precipitation                      0.0019      0.002      1.156      0.248      -0.001       0.005
# day_of_week_num                   -0.0496      0.023     -2.123      0.034      -0.095      -0.004
# ==================================================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:         accident_count   No. Observations:                27153
# Model:                            GLM   Df Residuals:                    27144
# Model Family:                 Poisson   Df Model:                            8
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -55791.
# Date:                    목, 05 6 2025   Deviance:                       38600.
# Time:                        03:20:41   Pearson chi2:                 2.85e+04
# No. Iterations:                     6   Pseudo R-squ. (CS):             0.8883
# Covariance Type:                  HC1
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.7397      0.020     36.153      0.000       0.700       0.780
# is_holiday[T.True]                -0.1998      0.015    -13.055      0.000      -0.230      -0.170
# weather_condition_약간흐림[T.True]     0.0866      0.015      5.723      0.000       0.057       0.116
# weather_condition_비[T.True]        0.0540      0.018      3.022      0.003       0.019       0.089
# weather_condition_흐림[T.True]       0.0622      0.015      4.237      0.000       0.033       0.091
# injury_count                       0.0838      0.003     30.001      0.000       0.078       0.089
# temperature                        0.0013      0.001      2.115      0.034    9.42e-05       0.002
# precipitation                     -0.0006      0.000     -1.882      0.060      -0.001    2.61e-05
# day_of_week_num                    0.0050      0.004      1.254      0.210      -0.003       0.013
# ==================================================================================================

# %%
game_day_volleyball = df_encoded[df_encoded['is_배구']]
no_game_day_volleyball = df_encoded[~df_encoded['is_배구']]

formula = """accident_count ~ is_post_season + injury_count + temperature + precipitation + is_holiday +
            weather_condition_약간흐림 + weather_condition_비 + weather_condition_흐림 + day_of_week_num
            """

model = smf.glm(formula=formula, data=game_day_volleyball, family=sm.families.Poisson()).fit(cov_type='HC1')
print(model.summary())

formula = """accident_count ~ injury_count + temperature + precipitation + is_holiday +
            weather_condition_약간흐림 + weather_condition_비 + weather_condition_흐림 + day_of_week_num
            """

model = smf.glm(formula=formula, data=no_game_day_volleyball, family=sm.families.Poisson()).fit(cov_type='HC1')
print(model.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:         accident_count   No. Observations:                  550
# Model:                            GLM   Df Residuals:                      540
# Model Family:                 Poisson   Df Model:                            9
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -1205.9
# Date:                    목, 05 6 2025   Deviance:                       645.94
# Time:                        03:21:59   Pearson chi2:                     541.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.9271
# Covariance Type:                  HC1
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.9503      0.068     14.033      0.000       0.818       1.083
# is_post_season[T.True]            -0.1159      0.108     -1.078      0.281      -0.327       0.095
# is_holiday[T.True]                -0.2341      0.070     -3.362      0.001      -0.371      -0.098
# weather_condition_약간흐림[T.True]     0.0010      0.069      0.014      0.989      -0.135       0.137
# weather_condition_비[T.True]        0.0128      0.061      0.209      0.834      -0.107       0.133
# weather_condition_흐림[T.True]      -0.0521      0.089     -0.584      0.559      -0.227       0.123
# injury_count                       0.0719      0.004     18.449      0.000       0.064       0.080
# temperature                        0.0022      0.003      0.736      0.461      -0.004       0.008
# precipitation                      0.0009      0.002      0.377      0.706      -0.004       0.006
# day_of_week_num                    0.0282      0.018      1.535      0.125      -0.008       0.064
# ==================================================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:         accident_count   No. Observations:                27025
# Model:                            GLM   Df Residuals:                    27016
# Model Family:                 Poisson   Df Model:                            8
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -55442.
# Date:                    목, 05 6 2025   Deviance:                       38330.
# Time:                        03:21:59   Pearson chi2:                 2.82e+04
# No. Iterations:                     6   Pseudo R-squ. (CS):             0.8865
# Covariance Type:                  HC1
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.7349      0.020     36.739      0.000       0.696       0.774
# is_holiday[T.True]                -0.1913      0.015    -12.634      0.000      -0.221      -0.162
# weather_condition_약간흐림[T.True]     0.0887      0.015      5.735      0.000       0.058       0.119
# weather_condition_비[T.True]        0.0540      0.018      2.971      0.003       0.018       0.090
# weather_condition_흐림[T.True]       0.0667      0.015      4.496      0.000       0.038       0.096
# injury_count                       0.0839      0.003     29.658      0.000       0.078       0.089
# temperature                        0.0015      0.001      2.499      0.012       0.000       0.003
# precipitation                     -0.0006      0.000     -1.772      0.076      -0.001    6.28e-05
# day_of_week_num                    0.0040      0.004      0.996      0.319      -0.004       0.012
# ==================================================================================================

# %%
game_day_basketball = df_encoded[df_encoded['is_농구']]
no_game_day_basketball = df_encoded[~df_encoded['is_농구']]

formula = """accident_count ~ is_post_season + injury_count + temperature + precipitation + is_holiday +
            weather_condition_약간흐림 + weather_condition_비 + weather_condition_흐림 + day_of_week_num
            """

model = smf.glm(formula=formula, data=game_day_basketball, family=sm.families.Poisson()).fit(cov_type='HC1')
print(model.summary())

formula = """accident_count ~ injury_count + temperature + precipitation + is_holiday +
            weather_condition_약간흐림 + weather_condition_비 + weather_condition_흐림 + day_of_week_num
            """

model = smf.glm(formula=formula, data=no_game_day_basketball, family=sm.families.Poisson()).fit(cov_type='HC1')
print(model.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:         accident_count   No. Observations:                  564
# Model:                            GLM   Df Residuals:                      554
# Model Family:                 Poisson   Df Model:                            9
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -1250.9
# Date:                    목, 05 6 2025   Deviance:                       1271.3
# Time:                        03:23:28   Pearson chi2:                     981.
# No. Iterations:                     6   Pseudo R-squ. (CS):             0.9473
# Covariance Type:                  HC1
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.6533      0.100      6.537      0.000       0.457       0.849
# is_post_season[T.True]            -0.1513      0.174     -0.870      0.384      -0.492       0.190
# is_holiday[T.True]                -0.1579      0.091     -1.728      0.084      -0.337       0.021
# weather_condition_약간흐림[T.True]     0.2958      0.095      3.111      0.002       0.109       0.482
# weather_condition_비[T.True]        0.2180      0.099      2.207      0.027       0.024       0.412
# weather_condition_흐림[T.True]       0.1552      0.100      1.549      0.121      -0.041       0.352
# injury_count                       0.0746      0.007     10.915      0.000       0.061       0.088
# temperature                       -0.0009      0.006     -0.133      0.895      -0.013       0.012
# precipitation                      0.0006      0.004      0.151      0.880      -0.007       0.008
# day_of_week_num                   -0.0081      0.024     -0.332      0.740      -0.056       0.039
# ==================================================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:         accident_count   No. Observations:                27011
# Model:                            GLM   Df Residuals:                    27002
# Model Family:                 Poisson   Df Model:                            8
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -55354.
# Date:                    목, 05 6 2025   Deviance:                       37619.
# Time:                        03:23:28   Pearson chi2:                 2.78e+04
# No. Iterations:                     6   Pseudo R-squ. (CS):             0.8873
# Covariance Type:                  HC1
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.7454      0.021     36.215      0.000       0.705       0.786
# is_holiday[T.True]                -0.1871      0.015    -12.689      0.000      -0.216      -0.158
# weather_condition_약간흐림[T.True]     0.0830      0.015      5.503      0.000       0.053       0.113
# weather_condition_비[T.True]        0.0470      0.018      2.565      0.010       0.011       0.083
# weather_condition_흐림[T.True]       0.0608      0.015      4.112      0.000       0.032       0.090
# injury_count                       0.0843      0.003     29.045      0.000       0.079       0.090
# temperature                        0.0010      0.001      1.748      0.081      -0.000       0.002
# precipitation                     -0.0006      0.000     -1.665      0.096      -0.001    9.91e-05
# day_of_week_num                    0.0046      0.004      1.094      0.274      -0.004       0.013
# ==================================================================================================
